# %% [markdown]
# ### 4-Bus System Power Flow Analysis

# %% [markdown]
# Power flow analysis of a 4-bus electrical system under normal operating conditions. The slack bus (Bus 1) is set to 1.03 pu, representing typical utility voltage regulation above nominal. This scenario analyzes system behavior with standard voltage levels and compares different load modeling approaches (constant power, constant current, constant impedance, and mixed ZIP models) to understand their impact on voltage profiles and convergence characteristics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.zmatrix_models import MetodoMatrizZdetailed

def exemplo_sistema_4_barras(v_slack=1.03):
    # Definir o sistema
    barras = [1, 2, 3, 4]
    
    # Barra 1 é a slack (tipo 0)
    # Barras 2, 3 e 4 são PQ (tipo 2)
    barras_tipo = {1: 0, 2: 2, 3: 2, 4: 2}  # 0: slack, 1: PV, 2: PQ
    
    # Potências complexas (S = P + jQ) em pu
    # Nota: as cargas são negativas do ponto de vista da injeção de potência
    potencias = {
        1: 0.0 - 0.7j,  # Barra slack
        2: -1.28 - 1.28j,
        3: -0.32 - 0.16j,
        4: -1.6 - 0.80j
    }
    
    # Tensões iniciais (flat start com valores de 1.0 pu, exceto a barra slack)
    v_inicial = {
        1: v_slack + 0.0j,  # Tensão de referência na barra slack
        2: 1.0 + 0.0j,
        3: 1.0 + 0.0j,
        4: 1.0 + 0.0j
    }
    
    # Definir os modelos de carga para cada barra (ZIP)
    # Formato: {barra: {'P': porcentagem_CP, 'I': porcentagem_CI, 'Z': porcentagem_CZ}}
    # Exemplo: Barra 2 com 60% potência constante, 30% corrente constante, 10% impedância constante
    # load_models = {
    #     1: {'P': 1.0, 'I': 0.0, 'Z': 0.0},  
    #     2: {'P': 1.0, 'I': 0.0, 'Z': 0.0},  
    #     3: {'P': 1.0, 'I': 0.0, 'Z': 0.0},  
    #     4: {'P': 1.0, 'I': 0.0, 'Z': 0.0},  
    # }
    
    # Linhas (conexões entre barras)
    linhas = [(1, 2), (2, 3), (2, 4)]
    
    # Calcular os elementos da matriz Y_bus
    
    # Impedâncias das linhas
    z12 = 0.0236 + 0.0233j
    z23 = 0.045 + 0.030j
    z24 = 0.0051 + 0.0005j
    
    # Admitâncias série das linhas
    y12 = 1 / z12
    y23 = 1 / z23
    y24 = 1 / z24
    
    # Admitância shunt total por linha (j0.01 pu)
    y_shunt = 0.01j
    
    # Construir a matriz de admitância Y_bus
    Y_bus = np.zeros((4, 4), dtype=complex)
    
    # Elementos diagonais (soma das admitâncias conectadas à barra)
    Y_bus[0, 0] = y12 + y_shunt/2  # Barra 1
    Y_bus[1, 1] = y12 + y23 + y24 + y_shunt/2 + y_shunt/2 + y_shunt/2  # Barra 2
    Y_bus[2, 2] = y23 + y_shunt/2  # Barra 3
    Y_bus[3, 3] = y24 + y_shunt/2  # Barra 4
    
    # Elementos não-diagonais (negativo da admitância entre as barras)
    Y_bus[0, 1] = Y_bus[1, 0] = -y12
    Y_bus[1, 2] = Y_bus[2, 1] = -y23
    Y_bus[1, 3] = Y_bus[3, 1] = -y24
    
    print("Matriz de Admitância Y_bus:")
    for i in range(4):
        row_str = ""
        for j in range(4):
            real = Y_bus[i, j].real
            imag = Y_bus[i, j].imag
            row_str += f"{real:.6f}{'+' if imag >= 0 else ''}{imag:.6f}j  "
        print(row_str)

    # Calcular e imprimir a matriz Z_bus (inversa da Y_bus reduzida)
    # Identifica a barra slack
    slack_bus = 1
    # Índices das barras não-slack
    barras_nao_slack = [b for b in barras if b != slack_bus]
    
    # Mapear índices originais para índices na matriz
    idx_map = {b: i for i, b in enumerate(barras)}
    idx_nao_slack = [idx_map[b] for b in barras_nao_slack]
    
    # Extrair a parte da Y_bus que corresponde às barras não-slack
    Y_reduzida = Y_bus[np.ix_(idx_nao_slack, idx_nao_slack)]
    
    # Calcular a matriz Z_bus (inversa da Y_bus reduzida)
    Z_bus = np.linalg.inv(Y_reduzida)
    
    print("\nMatriz de Impedância Z_bus (inversa da Y_bus reduzida):")
    print("Barras não-slack:", barras_nao_slack)
    for i, barra_i in enumerate(barras_nao_slack):
        row_str = f"Barra {barra_i}: "
        for j, barra_j in enumerate(barras_nao_slack):
            real = Z_bus[i, j].real
            imag = Z_bus[i, j].imag
            sign = "+" if imag >= 0 else ""
            row_str += f"Z{barra_i}{barra_j}={real:.6f}{sign}{imag:.6f}j  "
        print(row_str)
    
    # Tolerância conforme informado
    tolerancia = 0.0010
    
    # Criar instância do solver com os modelos de carga
    # solver = MetodoMatrizZdetailed(Y_bus, barras, linhas, barras_tipo, potencias, 
    #                            v_inicial, load_models=load_models, tol=tolerancia)
    
    # # Resolver usando método da matriz Z com substituição em bloco
    # v_bloco, v_history_bloco, iteracoes_bloco = solver.substituicao_em_bloco()
    # fluxos_bloco = solver.calcular_fluxos(v_bloco)
    
    # # Exibir resultados
    # solver.exibir_resultados(v_bloco, fluxos_bloco, "Substituição em Bloco", iteracoes_bloco)
    # solver.plotar_convergencia(v_history_bloco, "Substituição em Bloco")
    
    # # Resolver usando método da matriz Z com substituição direta
    # v_direta, v_history_direta, iteracoes_direta = solver.substituicao_direta()
    # fluxos_direta = solver.calcular_fluxos(v_direta)
    
    # # Exibir resultados
    # solver.exibir_resultados(v_direta, fluxos_direta, "Substituição Direta", iteracoes_direta)
    # solver.plotar_convergencia(v_history_direta, "Substituição Direta")
    
    # # Comparar número de iterações
    # print(f"\nComparação do número de iterações:")
    # print(f"Método de Substituição em Bloco: {iteracoes_bloco} iterações")
    # print(f"Método de Substituição Direta: {iteracoes_direta} iterações")
    
# Comparar resultados para diferentes combinações de modelos de carga
    print("\n--- Análise de Sensibilidade dos Modelos de Carga ---")
    
    # Definir diferentes cenários de modelos de carga
    load_scenarios = [
        {"name": "100% Potência Constante", "models": {
            1: {'P': 1.0, 'I': 0.0, 'Z': 0.0},
            2: {'P': 1.0, 'I': 0.0, 'Z': 0.0},
            3: {'P': 1.0, 'I': 0.0, 'Z': 0.0},
            4: {'P': 1.0, 'I': 0.0, 'Z': 0.0}
        }},
        {"name": "100% Corrente Constante", "models": {
            1: {'P': 0.0, 'I': 1.0, 'Z': 0.0},
            2: {'P': 0.0, 'I': 1.0, 'Z': 0.0},
            3: {'P': 0.0, 'I': 1.0, 'Z': 0.0},
            4: {'P': 0.0, 'I': 1.0, 'Z': 0.0}
        }},
        {"name": "100% Impedância Constante", "models": {
            1: {'P': 0.0, 'I': 0.0, 'Z': 1.0},
            2: {'P': 0.0, 'I': 0.0, 'Z': 1.0},
            3: {'P': 0.0, 'I': 0.0, 'Z': 1.0},
            4: {'P': 0.0, 'I': 0.0, 'Z': 1.0}
        }},
        {"name": "Modelo Misto (ZIP)", "models": {
            1: {'P': 0.4, 'I': 0.3, 'Z': 0.3},
            2: {'P': 0.4, 'I': 0.3, 'Z': 0.3},
            3: {'P': 0.4, 'I': 0.3, 'Z': 0.3},
            4: {'P': 0.4, 'I': 0.3, 'Z': 0.3}
        }}
    ]
    
    # Executar análise para cada cenário
    resultados_cenarios = []
    
    for scenario in load_scenarios:
        print(f"\nExecutando cenário: {scenario['name']}")
        solver_cenario = MetodoMatrizZdetailed(Y_bus, barras, linhas, barras_tipo, 
                                          potencias, v_inicial, 
                                          load_models=scenario['models'], 
                                          tol=tolerancia)
        
        # Usar método de substituição em bloco para todos os cenários
        v_final, _, iter_count = solver_cenario.substituicao_em_bloco()
        
        # Armazenar resultados
        v_magnitudes = [abs(v) for v in v_final]
        v_angulos = [np.angle(v, deg=True) for v in v_final]
        
        resultados_cenarios.append({
            "nome": scenario['name'],
            "iteracoes": iter_count,
            "magnitudes": v_magnitudes,
            "angulos": v_angulos
        })
    
    # Comparar resultados entre cenários
    print("\n--- Comparação de Resultados entre Cenários de Carga ---")
    print("{:<30} {:<10} {:<40} {:<40}".format(
        "Cenário", "Iterações", "Magnitudes de Tensão (pu)", "Ângulos de Fase (°)"))
    
    for resultado in resultados_cenarios:
        mags_str = ", ".join([f"{m:.4f}" for m in resultado["magnitudes"]])
        angs_str = ", ".join([f"{a:.2f}" for a in resultado["angulos"]])
        print("{:<30} {:<10} {:<40} {:<40}".format(
            resultado["nome"], resultado["iteracoes"], mags_str, angs_str))
    
    # Plotar comparação gráfica das magnitudes de tensão
    plt.figure(figsize=(12, 6))
    bar_width = 0.2
    x = np.arange(len(barras))
    
    for i, resultado in enumerate(resultados_cenarios):
        plt.bar(x + i*bar_width, resultado["magnitudes"], 
                width=bar_width, label=resultado["nome"])
    
    plt.xlabel('Barras')
    plt.ylabel('Magnitude da Tensão (pu)')
    plt.title('Comparação das Magnitudes de Tensão para Diferentes Modelos de Carga')
    plt.xticks(x + bar_width*1.5, [f'Barra {b}' for b in barras])
    plt.grid(True, axis='y', alpha=0.3)
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()

exemplo_sistema_4_barras()
# Out:
# Matriz de Admitância Y_bus:
# 21.457471-21.179707j  -21.457471+21.184707j  0.000000+0.000000j  0.000000+0.000000j
# -21.457471+21.184707j  231.053816-50.466483j  -15.384615+10.256410j  -194.211729+19.040366j
# 0.000000+0.000000j  -15.384615+10.256410j  15.384615-10.251410j  0.000000+0.000000j
# 0.000000+0.000000j  -194.211729+19.040366j  0.000000+0.000000j  194.211729-19.035366j
#
# Matriz de Impedância Z_bus (inversa da Y_bus reduzida):
# Barras não-slack: [2, 3, 4]
# Barra 2: Z22=0.023628+0.023300j  Z23=0.023636+0.023298j  Z24=0.023628+0.023299j
# Barra 3: Z32=0.023636+0.023298j  Z33=0.068659+0.053290j  Z34=0.023637+0.023297j
# Barra 4: Z42=0.023628+0.023299j  Z43=0.023637+0.023297j  Z44=0.028729+0.023798j
#
# --- Análise de Sensibilidade dos Modelos de Carga ---
#
# Executando cenário: 100% Potência Constante
#
# Constantes C:
# C2 = -1.030600+0.000608j
# C3 = -1.030754+0.000841j
# C4 = -1.030603+0.000635j
#
# Modelos de Carga Configurados:
# Barra 2: 100.0% Potência Constante, 0.0% Corrente Constante, 0.0% Impedância Constante
# Barra 3: 100.0% Potência Constante, 0.0% Corrente Constante, 0.0% Impedância Constante
# Barra 4: 100.0% Potência Constante, 0.0% Corrente Constante, 0.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V_novo3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V_novo4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -1.382052+1.451859j (mag=2.004485, ang=133.588940°)
# I3 = -0.356733+0.191079j (mag=0.404684, ang=151.824832°)
# I4 = -1.769444+0.932173j (mag=1.999970, ang=152.218972°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.887707-0.021502j (mag=0.887967, ang=-1.387514°)
# V_novo3 = 0.866046-0.023803j (mag=0.866373, ang=-1.574384°)
# V_novo4 = 0.878218-0.017655j (mag=0.878396, ang=-1.151647°)
#
# Iteração 3 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.887707-0.021502j (mag=0.887967, ang=-1.387514°)
# V3 = 0.866046-0.023803j (mag=0.866373, ang=-1.574384°)
# V4 = 0.878218-0.017655j (mag=0.878396, ang=-1.151647°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -1.406167+1.475977j (mag=2.038582, ang=133.612486°)
# I3 = -0.364143+0.194756j (mag=0.412953, ang=151.860565°)
# I4 = -1.802830+0.947177j (mag=2.036502, ang=152.283302°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.885176-0.022003j (mag=0.885449, ang=-1.423895°)
# V_novo3 = 0.863071-0.024361j (mag=0.863414, ang=-1.616780°)
# V_novo4 = 0.875509-0.018096j (mag=0.875696, ang=-1.184071°)
#
# Iteração 4 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.885176-0.022003j (mag=0.885449, ang=-1.423895°)
# V3 = 0.863071-0.024361j (mag=0.863414, ang=-1.616780°)
# V4 = 0.875509-0.018096j (mag=0.875696, ang=-1.184071°)
#
# Iteração 4 - Correntes injetadas (modelo ZIP):
# I2 = -1.409226+1.481069j (mag=2.044379, ang=133.576105°)
# I3 = -0.365246+0.195694j (mag=0.414368, ang=151.818169°)
# I4 = -1.807849+0.951120j (mag=2.042779, ang=152.250878°)
#
# Iteração 4 - Novas tensões calculadas:
# V_novo2 = 0.884726-0.021981j (mag=0.884999, ang=-1.423211°)
# V_novo3 = 0.862543-0.024330j (mag=0.862887, ang=-1.615712°)
# V_novo4 = 0.875033-0.018056j (mag=0.875219, ang=-1.182140°)
#
# Executando cenário: 100% Corrente Constante
#
# Constantes C:
# C2 = -1.030600+0.000608j
# C3 = -1.030754+0.000841j
# C4 = -1.030603+0.000635j
#
# Modelos de Carga Configurados:
# Barra 2: 0.0% Potência Constante, 100.0% Corrente Constante, 0.0% Impedância Constante
# Barra 3: 0.0% Potência Constante, 100.0% Corrente Constante, 0.0% Impedância Constante
# Barra 4: 0.0% Potência Constante, 100.0% Corrente Constante, 0.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V_novo3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V_novo4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -1.248092+1.311132j (mag=1.810193, ang=133.588940°)
# I3 = -0.315378+0.168928j (mag=0.357771, ang=151.824832°)
# I4 = -1.582663+0.833774j (mag=1.788854, ang=152.218972°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.902350-0.019239j (mag=0.902555, ang=-1.221391°)
# V_novo3 = 0.883218-0.021300j (mag=0.883475, ang=-1.381502°)
# V_novo4 = 0.893864-0.015800j (mag=0.894003, ang=-1.012691°)
#
# Iteração 3 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.902350-0.019239j (mag=0.902555, ang=-1.221391°)
# V3 = 0.883218-0.021300j (mag=0.883475, ang=-1.381502°)
# V4 = 0.893864-0.015800j (mag=0.894003, ang=-1.012691°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -1.252425+1.306993j (mag=1.810193, ang=133.778609°)
# I3 = -0.316049+0.167669j (mag=0.357771, ang=152.053447°)
# I4 = -1.585611+0.828153j (mag=1.788854, ang=152.422258°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.902419-0.019684j (mag=0.902634, ang=-1.249581°)
# V_novo3 = 0.883294-0.021823j (mag=0.883564, ang=-1.415261°)
# V_novo4 = 0.893920-0.016276j (mag=0.894068, ang=-1.043114°)
#
# Executando cenário: 100% Impedância Constante
#
# Constantes C:
# C2 = -1.030600+0.000608j
# C3 = -1.030754+0.000841j
# C4 = -1.030603+0.000635j
#
# Modelos de Carga Configurados:
# Barra 2: 0.0% Potência Constante, 0.0% Corrente Constante, 100.0% Impedância Constante
# Barra 3: 0.0% Potência Constante, 0.0% Corrente Constante, 100.0% Impedância Constante
# Barra 4: 0.0% Potência Constante, 0.0% Corrente Constante, 100.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V_novo3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V_novo4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -1.127116+1.184046j (mag=1.634734, ang=133.588940°)
# I3 = -0.278817+0.149345j (mag=0.316296, ang=151.824832°)
# I4 = -1.415598+0.745761j (mag=1.600024, ang=152.218972°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.915488-0.017221j (mag=0.915650, ang=-1.077638°)
# V_novo3 = 0.898591-0.019070j (mag=0.898794, ang=-1.215746°)
# V_novo4 = 0.907897-0.014148j (mag=0.908008, ang=-0.892810°)
#
# Iteração 3 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.915488-0.017221j (mag=0.915650, ang=-1.077638°)
# V3 = 0.898591-0.019070j (mag=0.898794, ang=-1.215746°)
# V4 = 0.907897-0.014148j (mag=0.908008, ang=-0.892810°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -1.149782+1.193867j (mag=1.657503, ang=133.922362°)
# I3 = -0.284498+0.149877j (mag=0.321562, ang=152.219203°)
# I4 = -1.441317+0.748955j (mag=1.624294, ang=152.542139°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.913895-0.018160j (mag=0.914075, ang=-1.138400°)
# V_novo3 = 0.896726-0.020156j (mag=0.896953, ang=-1.287618°)
# V_novo4 = 0.906172-0.015085j (mag=0.906297, ang=-0.953684°)
#
# Iteração 4 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.913895-0.018160j (mag=0.914075, ang=-1.138400°)
# V3 = 0.896726-0.020156j (mag=0.896953, ang=-1.287618°)
# V4 = 0.906172-0.015085j (mag=0.906297, ang=-0.953684°)
#
# Iteração 4 - Correntes injetadas (modelo ZIP):
# I2 = -1.146540+1.193031j (mag=1.654653, ang=133.861600°)
# I3 = -0.283727+0.149926j (mag=0.320904, ang=152.147330°)
# I4 = -1.437807+0.749073j (mag=1.621234, ang=152.481265°)
#
# Iteração 4 - Novas tensões calculadas:
# V_novo2 = 0.914088-0.018001j (mag=0.914265, ang=-1.128170°)
# V_novo3 = 0.896953-0.019971j (mag=0.897175, ang=-1.275498°)
# V_novo4 = 0.906383-0.014923j (mag=0.906506, ang=-0.943237°)
#
# Executando cenário: Modelo Misto (ZIP)
#
# Constantes C:
# C2 = -1.030600+0.000608j
# C3 = -1.030754+0.000841j
# C4 = -1.030603+0.000635j
#
# Modelos de Carga Configurados:
# Barra 2: 40.0% Potência Constante, 30.0% Corrente Constante, 30.0% Impedância Constante
# Barra 3: 40.0% Potência Constante, 30.0% Corrente Constante, 30.0% Impedância Constante
# Barra 4: 40.0% Potência Constante, 30.0% Corrente Constante, 30.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V_novo3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V_novo4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.902798-0.022238j (mag=0.903071, ang=-1.411060°)
# V3 = 0.883725-0.024841j (mag=0.884074, ang=-1.610117°)
# V4 = 0.894239-0.018981j (mag=0.894441, ang=-1.215977°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -1.265383+1.329297j (mag=1.835272, ang=133.588940°)
# I3 = -0.320952+0.171914j (mag=0.364094, ang=151.824832°)
# I4 = -1.607256+0.846730j (mag=1.816651, ang=152.218972°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.900434-0.019538j (mag=0.900646, ang=-1.243060°)
# V_novo3 = 0.880961-0.021632j (mag=0.881227, ang=-1.406636°)
# V_novo4 = 0.891816-0.016047j (mag=0.891960, ang=-1.030817°)
#
# Iteração 3 - Tensões atuais:
# V1 = 1.030000+0.000000j (mag=1.030000, ang=0.000000°)
# V2 = 0.900434-0.019538j (mag=0.900646, ang=-1.243060°)
# V3 = 0.880961-0.021632j (mag=0.881227, ang=-1.406636°)
# V4 = 0.891816-0.016047j (mag=0.891960, ang=-1.030817°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -1.269858+1.326189j (mag=1.836114, ang=133.756940°)
# I3 = -0.321752+0.170875j (mag=0.364311, ang=152.028313°)
# I4 = -1.610776+0.841945j (mag=1.817545, ang=152.404132°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.900434-0.019954j (mag=0.900655, ang=-1.269515°)
# V_novo3 = 0.880956-0.022119j (mag=0.881234, ang=-1.438284°)
# V_novo4 = 0.891800-0.016489j (mag=0.891953, ang=-1.059230°)
#
# --- Comparação de Resultados entre Cenários de Carga ---
# Cenário                        Iterações  Magnitudes de Tensão (pu)                Ângulos de Fase (°)
# 100% Potência Constante        4          1.0300, 0.8850, 0.8629, 0.8752           0.00, -1.42, -1.62, -1.18
# 100% Corrente Constante        3          1.0300, 0.9026, 0.8836, 0.8941           0.00, -1.25, -1.42, -1.04
# 100% Impedância Constante      4          1.0300, 0.9143, 0.8972, 0.9065           0.00, -1.13, -1.28, -0.94
# Modelo Misto (ZIP)             3          1.0300, 0.9007, 0.8812, 0.8920           0.00, -1.27, -1.44, -1.06

# %% [markdown]
# Power flow analysis of the same 4-bus electrical system under stressed voltage conditions. The slack bus (Bus 1) is set to 0.72 pu, representing a significant voltage depression (28% below nominal). This scenario examines how the system responds to voltage stress conditions and evaluates the sensitivity of different load models to low voltage operation, which is critical for understanding system stability margins and load behavior during voltage disturbances or heavy loading conditions.

# %%
exemplo_sistema_4_barras(v_slack=0.72)
# Out:
# Matriz de Admitância Y_bus:
# 21.457471-21.179707j  -21.457471+21.184707j  0.000000+0.000000j  0.000000+0.000000j
# -21.457471+21.184707j  231.053816-50.466483j  -15.384615+10.256410j  -194.211729+19.040366j
# 0.000000+0.000000j  -15.384615+10.256410j  15.384615-10.251410j  0.000000+0.000000j
# 0.000000+0.000000j  -194.211729+19.040366j  0.000000+0.000000j  194.211729-19.035366j
#
# Matriz de Impedância Z_bus (inversa da Y_bus reduzida):
# Barras não-slack: [2, 3, 4]
# Barra 2: Z22=0.023628+0.023300j  Z23=0.023636+0.023298j  Z24=0.023628+0.023299j
# Barra 3: Z32=0.023636+0.023298j  Z33=0.068659+0.053290j  Z34=0.023637+0.023297j
# Barra 4: Z42=0.023628+0.023299j  Z43=0.023637+0.023297j  Z44=0.028729+0.023798j
#
# --- Análise de Sensibilidade dos Modelos de Carga ---
#
# Executando cenário: 100% Potência Constante
#
# Constantes C:
# C2 = -0.720419+0.000425j
# C3 = -0.720527+0.000588j
# C4 = -0.720421+0.000444j
#
# Modelos de Carga Configurados:
# Barra 2: 100.0% Potência Constante, 0.0% Corrente Constante, 0.0% Impedância Constante
# Barra 3: 100.0% Potência Constante, 0.0% Corrente Constante, 0.0% Impedância Constante
# Barra 4: 100.0% Potência Constante, 0.0% Corrente Constante, 0.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V_novo3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V_novo4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -2.076650+2.237197j (mag=3.052462, ang=132.868635°)
# I3 = -0.545017+0.302357j (mag=0.623268, ang=150.979980°)
# I4 = -2.692601+1.456352j (mag=3.061219, ang=151.592288°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.501748-0.029826j (mag=0.502634, ang=-3.401946°)
# V_novo3 = 0.468215-0.032681j (mag=0.469354, ang=-3.992740°)
# V_novo4 = 0.487288-0.023758j (mag=0.487867, ang=-2.791255°)
#
# Iteração 3 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.501748-0.029826j (mag=0.502634, ang=-3.401946°)
# V3 = 0.468215-0.032681j (mag=0.469354, ang=-3.992740°)
# V4 = 0.487288-0.023758j (mag=0.487867, ang=-2.791255°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -2.390983+2.693213j (mag=3.601415, ang=131.598054°)
# I3 = -0.656397+0.387540j (mag=0.762263, ang=149.442209°)
# I4 = -3.195837+1.797552j (mag=3.666683, ang=150.643694°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.459239-0.030620j (mag=0.460259, ang=-3.814614°)
# V_novo3 = 0.418130-0.032972j (mag=0.419428, ang=-4.508765°)
# V_novo4 = 0.442042-0.023062j (mag=0.442643, ang=-2.986501°)
#
# Iteração 4 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.459239-0.030620j (mag=0.460259, ang=-3.814614°)
# V3 = 0.418130-0.032972j (mag=0.419428, ang=-4.508765°)
# V4 = 0.442042-0.023062j (mag=0.442643, ang=-2.986501°)
#
# Iteração 4 - Correntes injetadas (modelo ZIP):
# I2 = -2.589866+2.959903j (mag=3.932992, ang=131.185386°)
# I3 = -0.730595+0.440268j (mag=0.852997, ang=148.926184°)
# I4 = -3.515579+1.993197j (mag=4.041303, ang=150.448448°)
#
# Iteração 4 - Novas tensões calculadas:
# V_novo2 = 0.433231-0.032262j (mag=0.434430, ang=-4.258901°)
# V_novo3 = 0.387196-0.034460j (mag=0.388727, ang=-5.085909°)
# V_novo4 = 0.414305-0.023865j (mag=0.414992, ang=-3.296789°)
#
# Iteração 5 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.433231-0.032262j (mag=0.434430, ang=-4.258901°)
# V3 = 0.387196-0.034460j (mag=0.388727, ang=-5.085909°)
# V4 = 0.414305-0.023865j (mag=0.414992, ang=-3.296789°)
#
# Iteração 5 - Correntes injetadas (modelo ZIP):
# I2 = -2.719444+3.157062j (mag=4.166823, ang=130.741099°)
# I3 = -0.783472+0.482956j (mag=0.920367, ang=148.349040°)
# I4 = -3.738257+2.146281j (mag=4.310579, ang=150.138160°)
#
# Iteração 5 - Novas tensões calculadas:
# V_novo2 = 0.414503-0.032417j (mag=0.415768, ang=-4.471831°)
# V_novo3 = 0.364805-0.034275j (mag=0.366411, ang=-5.367491°)
# V_novo4 = 0.394365-0.023350j (mag=0.395055, ang=-3.388511°)
#
# Iteração 6 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.414503-0.032417j (mag=0.415768, ang=-4.471831°)
# V3 = 0.364805-0.034275j (mag=0.366411, ang=-5.367491°)
# V4 = 0.394365-0.023350j (mag=0.395055, ang=-3.388511°)
#
# Iteração 6 - Correntes injetadas (modelo ZIP):
# I2 = -2.829228+3.309304j (mag=4.353852, ang=130.528169°)
# I3 = -0.828659+0.516448j (mag=0.976419, ang=148.067458°)
# I4 = -3.923292+2.260876j (mag=4.528110, ang=150.046437°)
#
# Iteração 6 - Novas tensões calculadas:
# V_novo2 = 0.399471-0.033242j (mag=0.400852, ang=-4.756975°)
# V_novo3 = 0.346732-0.034945j (mag=0.348489, ang=-5.755108°)
# V_novo4 = 0.378332-0.023683j (mag=0.379073, ang=-3.582003°)
#
# Iteração 7 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.399471-0.033242j (mag=0.400852, ang=-4.756975°)
# V3 = 0.346732-0.034945j (mag=0.348489, ang=-5.755108°)
# V4 = 0.378332-0.023683j (mag=0.379073, ang=-3.582003°)
#
# Iteração 7 - Correntes injetadas (modelo ZIP):
# I2 = -2.917389+3.447010j (mag=4.515865, ang=130.243025°)
# I3 = -0.867583+0.548890j (mag=1.026635, ang=147.679841°)
# I4 = -4.080727+2.369994j (mag=4.719026, ang=149.852946°)
#
# Iteração 7 - Novas tensões calculadas:
# V_novo2 = 0.386242-0.033273j (mag=0.387672, ang=-4.923591°)
# V_novo3 = 0.330775-0.034680j (mag=0.332588, ang=-5.985254°)
# V_novo4 = 0.364245-0.023236j (mag=0.364985, ang=-3.650004°)
#
# Iteração 8 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.386242-0.033273j (mag=0.387672, ang=-4.923591°)
# V3 = 0.330775-0.034680j (mag=0.332588, ang=-5.985254°)
# V4 = 0.364245-0.023236j (mag=0.364985, ang=-3.650004°)
#
# Iteração 8 - Correntes injetadas (modelo ZIP):
# I2 = -3.006196+3.572958j (mag=4.669394, ang=130.076409°)
# I3 = -0.906742+0.578778j (mag=1.075717, ang=147.449695°)
# I4 = -4.235306+2.466497j (mag=4.901166, ang=149.784945°)
#
# Iteração 8 - Novas tensões calculadas:
# V_novo2 = 0.373686-0.033893j (mag=0.375220, ang=-5.182559°)
# V_novo3 = 0.315559-0.035127j (mag=0.317508, ang=-6.351820°)
# V_novo4 = 0.350853-0.023441j (mag=0.351635, ang=-3.822321°)
#
# Iteração 9 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.373686-0.033893j (mag=0.375220, ang=-5.182559°)
# V3 = 0.315559-0.035127j (mag=0.317508, ang=-6.351820°)
# V4 = 0.350853-0.023441j (mag=0.351635, ang=-3.822321°)
#
# Iteração 9 - Correntes injetadas (modelo ZIP):
# I2 = -3.089244+3.705532j (mag=4.824354, ang=129.817441°)
# I3 = -0.945912+0.612333j (mag=1.126810, ang=147.083128°)
# I4 = -4.388387+2.573351j (mag=5.087247, ang=149.612628°)
#
# Iteração 9 - Novas tensões calculadas:
# V_novo2 = 0.360821-0.033857j (mag=0.362406, ang=-5.360607°)
# V_novo3 = 0.299922-0.034752j (mag=0.301928, ang=-6.609472°)
# V_novo4 = 0.337153-0.022936j (mag=0.337933, ang=-3.891754°)
#
# Iteração 10 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.360821-0.033857j (mag=0.362406, ang=-5.360607°)
# V3 = 0.299922-0.034752j (mag=0.301928, ang=-6.609472°)
# V4 = 0.337153-0.022936j (mag=0.337933, ang=-3.891754°)
#
# Iteração 10 - Correntes injetadas (modelo ZIP):
# I2 = -3.186538+3.846476j (mag=4.994938, ang=129.639393°)
# I3 = -0.991814+0.648396j (mag=1.184953, ang=146.825477°)
# I4 = -4.563078+2.683227j (mag=5.293523, ang=149.543194°)
#
# Iteração 10 - Novas tensões calculadas:
# V_novo2 = 0.346625-0.034485j (mag=0.348336, ang=-5.681560°)
# V_novo3 = 0.282576-0.035131j (mag=0.284751, ang=-7.086801°)
# V_novo4 = 0.322012-0.023090j (mag=0.322839, ang=-4.101480°)
#
# Iteração 11 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.346625-0.034485j (mag=0.348336, ang=-5.681560°)
# V3 = 0.282576-0.035131j (mag=0.284751, ang=-7.086801°)
# V4 = 0.322012-0.023090j (mag=0.322839, ang=-4.101480°)
#
# Iteração 11 - Correntes injetadas (modelo ZIP):
# I2 = -3.292774+4.020343j (mag=5.196684, ang=129.318440°)
# I3 = -1.045880+0.696246j (mag=1.256432, ang=146.348148°)
# I4 = -4.766106+2.826142j (mag=5.541015, ang=149.333469°)
#
# Iteração 11 - Novas tensões calculadas:
# V_novo2 = 0.329544-0.034334j (mag=0.331328, ang=-5.948051°)
# V_novo3 = 0.261624-0.034444j (mag=0.263881, ang=-7.500079°)
# V_novo4 = 0.303824-0.022312j (mag=0.304642, ang=-4.200095°)
#
# Iteração 12 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.329544-0.034334j (mag=0.331328, ang=-5.948051°)
# V3 = 0.261624-0.034444j (mag=0.263881, ang=-7.500079°)
# V4 = 0.303824-0.022312j (mag=0.304642, ang=-4.200095°)
#
# Iteração 12 - Correntes injetadas (modelo ZIP):
# I2 = -3.442108+4.242778j (mag=5.463448, ang=129.051949°)
# I3 = -1.123148+0.759432j (mag=1.355802, ang=145.934870°)
# I4 = -5.045625+3.003638j (mag=5.871982, ang=149.234854°)
#
# Iteração 12 - Novas tensões calculadas:
# V_novo2 = 0.306795-0.035184j (mag=0.308806, ang=-6.542175°)
# V_novo3 = 0.233497-0.034761j (mag=0.236071, ang=-8.467589°)
# V_novo4 = 0.279560-0.022395j (mag=0.280456, ang=-4.580080°)
#
# Iteração 13 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.306795-0.035184j (mag=0.308806, ang=-6.542175°)
# V3 = 0.233497-0.034761j (mag=0.236071, ang=-8.467589°)
# V4 = 0.279560-0.022395j (mag=0.280456, ang=-4.580080°)
#
# Iteração 13 - Correntes injetadas (modelo ZIP):
# I2 = -3.645752+4.590270j (mag=5.861918, ang=128.457825°)
# I3 = -1.240950+0.869976j (mag=1.515525, ang=144.967360°)
# I4 = -5.458999+3.298946j (mag=6.378379, ang=148.854869°)
#
# Iteração 13 - Novas tensões calculadas:
# V_novo2 = 0.271879-0.034503j (mag=0.274060, ang=-7.232575°)
# V_novo3 = 0.189958-0.032631j (mag=0.192741, ang=-9.747001°)
# V_novo4 = 0.242389-0.020414j (mag=0.243247, ang=-4.814206°)
#
# Iteração 14 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.271879-0.034503j (mag=0.274060, ang=-7.232575°)
# V3 = 0.189958-0.032631j (mag=0.192741, ang=-9.747001°)
# V4 = 0.242389-0.020414j (mag=0.243247, ang=-4.814206°)
#
# Iteração 14 - Correntes injetadas (modelo ZIP):
# I2 = -4.045346+5.221356j (mag=6.605103, ang=127.767425°)
# I3 = -1.495757+1.099228j (mag=1.856230, ang=143.687947°)
# I4 = -6.278453+3.829265j (mag=7.354063, ang=148.620743°)
#
# Iteração 14 - Novas tensões calculadas:
# V_novo2 = 0.204652-0.035983j (mag=0.207791, ang=-9.972043°)
# V_novo3 = 0.104374-0.031418j (mag=0.109001, ang=-16.752621°)
# V_novo4 = 0.170717-0.019597j (mag=0.171838, ang=-6.548471°)
#
# Iteração 15 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.204652-0.035983j (mag=0.207791, ang=-9.972043°)
# V3 = 0.104374-0.031418j (mag=0.109001, ang=-16.752621°)
# V4 = 0.170717-0.019597j (mag=0.171838, ang=-6.548471°)
#
# Iteração 15 - Correntes injetadas (modelo ZIP):
# I2 = -5.000253+7.133690j (mag=8.711605, ang=125.027957°)
# I3 = -2.388061+2.251786j (mag=3.282282, ang=136.682327°)
# I4 = -8.719407+5.687043j (mag=10.410116, ang=146.886477°)
#
# Iteração 15 - Novas tensões calculadas:
# V_novo2 = -0.011370-0.019571j (mag=0.022633, ang=-120.154511°)
# V_novo3 = -0.186412+0.010161j (mag=0.186688, ang=176.879851°)
# V_novo4 = -0.058682+0.005075j (mag=0.058901, ang=175.057035°)
#
# Iteração 16 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = -0.011370-0.019571j (mag=0.022633, ang=-120.154511°)
# V3 = -0.186412+0.010161j (mag=0.186688, ang=176.879851°)
# V4 = -0.058682+0.005075j (mag=0.058901, ang=175.057035°)
#
# Iteração 16 - Correntes injetadas (modelo ZIP):
# I2 = 77.308962+20.491585j (mag=79.978627, ang=14.845489°)
# I3 = 1.664897-0.949071j (mag=1.916408, ang=-29.685201°)
# I4 = 25.892859-15.872147j (mag=30.370466, ang=-31.508016°)
#
# Iteração 16 - Novas tensões calculadas:
# V_novo2 = 3.112662+2.529616j (mag=4.010938, ang=39.100272°)
# V_novo3 = 3.217108+2.536512j (mag=4.096788, ang=38.253827°)
# V_novo4 = 3.252722+2.461538j (mag=4.079139, ang=37.117065°)
#
# Iteração 17 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 3.112662+2.529616j (mag=4.010938, ang=39.100272°)
# V3 = 3.217108+2.536512j (mag=4.096788, ang=38.253827°)
# V4 = 3.252722+2.461538j (mag=4.079139, ang=37.117065°)
#
# Iteração 17 - Correntes injetadas (modelo ZIP):
# I2 = -0.448924+0.046390j (mag=0.451314, ang=174.100272°)
# I3 = -0.085519-0.017693j (mag=0.087330, ang=-168.311224°)
# I4 = -0.431121-0.080308j (mag=0.438537, ang=-169.447986°)
#
# Iteração 17 - Novas tensões calculadas:
# V_novo2 = 0.698807-0.024142j (mag=0.699224, ang=-1.978626°)
# V_novo3 = 0.695587-0.027664j (mag=0.696137, ang=-2.277514°)
# V_novo4 = 0.696649-0.024785j (mag=0.697090, ang=-2.037564°)
#
# Iteração 18 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.698807-0.024142j (mag=0.699224, ang=-1.978626°)
# V3 = 0.695587-0.027664j (mag=0.696137, ang=-2.277514°)
# V4 = 0.696649-0.024785j (mag=0.697090, ang=-2.037564°)
#
# Iteração 18 - Correntes injetadas (modelo ZIP):
# I2 = -1.766305+1.892714j (mag=2.588861, ang=133.021374°)
# I3 = -0.450183+0.247926j (mag=0.513937, ang=151.157435°)
# I4 = -2.253000+1.228509j (mag=2.566173, ang=151.397385°)
#
# Iteração 18 - Novas tensões calculadas:
# V_novo2 = 0.536312-0.024953j (mag=0.536892, ang=-2.663892°)
# V_novo3 = 0.508686-0.027421j (mag=0.509425, ang=-3.085516°)
# V_novo4 = 0.524209-0.019828j (mag=0.524583, ang=-2.166120°)
#
# Iteração 19 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.536312-0.024953j (mag=0.536892, ang=-2.663892°)
# V3 = 0.508686-0.027421j (mag=0.509425, ang=-3.085516°)
# V4 = 0.524209-0.019828j (mag=0.524583, ang=-2.166120°)
#
# Iteração 19 - Correntes injetadas (modelo ZIP):
# I2 = -2.270709+2.492319j (mag=3.371613, ang=132.336108°)
# I3 = -0.610343+0.347436j (mag=0.702303, ang=150.349432°)
# I4 = -2.990219+1.639212j (mag=3.410048, ang=151.268829°)
#
# Iteração 19 - Novas tensões calculadas:
# V_novo2 = 0.477332-0.031390j (mag=0.478363, ang=-3.762439°)
# V_novo3 = 0.439502-0.034170j (mag=0.440828, ang=-4.445608°)
# V_novo4 = 0.461263-0.024537j (mag=0.461915, ang=-3.044997°)
#
# Iteração 20 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.477332-0.031390j (mag=0.478363, ang=-3.762439°)
# V3 = 0.439502-0.034170j (mag=0.440828, ang=-4.445608°)
# V4 = 0.461263-0.024537j (mag=0.461915, ang=-3.044997°)
#
# Iteração 20 - Correntes injetadas (modelo ZIP):
# I2 = -2.494441+2.845611j (mag=3.784143, ang=131.237561°)
# I3 = -0.695589+0.418128j (mag=0.811589, ang=148.989341°)
# I4 = -3.366952+1.913476j (mag=3.872694, ang=150.389952°)
#
# Iteração 20 - Novas tensões calculadas:
# V_novo2 = 0.444860-0.030868j (mag=0.445930, ang=-3.969262°)
# V_novo3 = 0.401068-0.033015j (mag=0.402424, ang=-4.705843°)
# V_novo4 = 0.426733-0.022804j (mag=0.427342, ang=-3.058836°)
#
# Iteração 21 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.444860-0.030868j (mag=0.445930, ang=-3.969262°)
# V3 = 0.401068-0.033015j (mag=0.402424, ang=-4.705843°)
# V4 = 0.426733-0.022804j (mag=0.427342, ang=-3.058836°)
#
# Iteração 21 - Correntes injetadas (modelo ZIP):
# I2 = -2.664827+3.062213j (mag=4.059365, ang=131.030738°)
# I3 = -0.759882+0.461487j (mag=0.889039, ang=148.729106°)
# I4 = -3.638848+2.069161j (mag=4.186005, ang=150.376113°)
#
# Iteração 21 - Novas tensões calculadas:
# V_novo2 = 0.423206-0.032849j (mag=0.424479, ang=-4.438420°)
# V_novo3 = 0.375216-0.034969j (mag=0.376842, ang=-5.324368°)
# V_novo4 = 0.403614-0.024127j (mag=0.404335, ang=-3.420851°)
#
# Iteração 22 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.423206-0.032849j (mag=0.424479, ang=-4.438420°)
# V3 = 0.375216-0.034969j (mag=0.376842, ang=-5.324368°)
# V4 = 0.403614-0.024127j (mag=0.404335, ang=-3.420851°)
#
# Iteração 22 - Correntes injetadas (modelo ZIP):
# I2 = -2.773056+3.239774j (mag=4.264502, ang=130.561580°)
# I3 = -0.806101+0.501547j (mag=0.949393, ang=148.110581°)
# I4 = -3.832008+2.211154j (mag=4.424193, ang=150.014098°)
#
# Iteração 22 - Novas tensões calculadas:
# V_novo2 = 0.406614-0.032451j (mag=0.407907, ang=-4.563004°)
# V_novo3 = 0.355339-0.034150j (mag=0.356976, ang=-5.489520°)
# V_novo4 = 0.385966-0.023100j (mag=0.386656, ang=-3.425086°)
#
# Iteração 23 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.406614-0.032451j (mag=0.407907, ang=-4.563004°)
# V3 = 0.355339-0.034150j (mag=0.356976, ang=-5.489520°)
# V4 = 0.385966-0.023100j (mag=0.386656, ang=-3.425086°)
#
# Iteração 23 - Correntes injetadas (modelo ZIP):
# I2 = -2.878382+3.377667j (mag=4.437760, ang=130.436996°)
# I3 = -0.849430+0.531909j (mag=1.002227, ang=147.945429°)
# I4 = -4.007040+2.312546j (mag=4.626471, ang=150.009863°)
#
# Iteração 23 - Novas tensões calculadas:
# V_novo2 = 0.392683-0.033621j (mag=0.394120, ang=-4.893710°)
# V_novo3 = 0.338544-0.035250j (mag=0.340375, ang=-5.944325°)
# V_novo4 = 0.371091-0.023840j (mag=0.371856, ang=-3.675868°)
#
# Iteração 24 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.392683-0.033621j (mag=0.394120, ang=-4.893710°)
# V3 = 0.338544-0.035250j (mag=0.340375, ang=-5.944325°)
# V4 = 0.371091-0.023840j (mag=0.371856, ang=-3.675868°)
#
# Iteração 24 - Correntes injetadas (modelo ZIP):
# I2 = -2.958847+3.512961j (mag=4.593003, ang=130.106290°)
# I3 = -0.886404+0.564906j (mag=1.051109, ang=147.490624°)
# I4 = -4.155957+2.422800j (mag=4.810607, ang=149.759081°)
#
# Iteração 24 - Novas tensões calculadas:
# V_novo2 = 0.379899-0.033246j (mag=0.381351, ang=-5.001293°)
# V_novo3 = 0.323105-0.034495j (mag=0.324941, ang=-6.093835°)
# V_novo4 = 0.357493-0.022976j (mag=0.358231, ang=-3.677395°)
#
# Iteração 25 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.379899-0.033246j (mag=0.381351, ang=-5.001293°)
# V3 = 0.323105-0.034495j (mag=0.324941, ang=-6.093835°)
# V4 = 0.357493-0.022976j (mag=0.358231, ang=-3.677395°)
#
# Iteração 25 - Correntes injetadas (modelo ZIP):
# I2 = -3.051093+3.636318j (mag=4.746786, ang=129.998707°)
# I3 = -0.926958+0.594158j (mag=1.101034, ang=147.341114°)
# I4 = -4.313967+2.515069j (mag=4.993584, ang=149.757554°)
#
# Iteração 25 - Novas tensões calculadas:
# V_novo2 = 0.367322-0.034235j (mag=0.368914, ang=-5.324664°)
# V_novo3 = 0.307823-0.035381j (mag=0.309849, ang=-6.556808°)
# V_novo4 = 0.344064-0.023574j (mag=0.344871, ang=-3.919558°)
#
# Iteração 26 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.367322-0.034235j (mag=0.368914, ang=-5.324664°)
# V3 = 0.307823-0.035381j (mag=0.309849, ang=-6.556808°)
# V4 = 0.344064-0.023574j (mag=0.344871, ang=-3.919558°)
#
# Iteração 26 - Correntes injetadas (modelo ZIP):
# I2 = -3.132688+3.776648j (mag=4.906812, ang=129.675336°)
# I3 = -0.967040+0.630931j (mag=1.154660, ang=146.878141°)
# I4 = -4.470004+2.631417j (mag=5.187031, ang=149.515390°)
#
# Iteração 26 - Novas tensões calculadas:
# V_novo2 = 0.353923-0.033772j (mag=0.355531, ang=-5.450689°)
# V_novo3 = 0.291514-0.034462j (mag=0.293544, ang=-6.741970°)
# V_novo4 = 0.329811-0.022595j (mag=0.330584, ang=-3.919112°)
#
# Iteração 27 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.353923-0.033772j (mag=0.355531, ang=-5.450689°)
# V3 = 0.291514-0.034462j (mag=0.293544, ang=-6.741970°)
# V4 = 0.329811-0.022595j (mag=0.330584, ang=-3.919112°)
#
# Iteração 27 - Correntes injetadas (modelo ZIP):
# I2 = -3.241988+3.925957j (mag=5.091525, ang=129.549311°)
# I3 = -1.018598+0.669272j (mag=1.218797, ang=146.692978°)
# I4 = -4.663207+2.745103j (mag=5.411200, ang=149.515836°)
#
# Iteração 27 - Novas tensões calculadas:
# V_novo2 = 0.338536-0.034901j (mag=0.340330, ang=-5.885975°)
# V_novo3 = 0.272654-0.035408j (mag=0.274943, ang=-7.399239°)
# V_novo4 = 0.313381-0.023240j (mag=0.314242, ang=-4.241258°)
#
# Iteração 28 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.338536-0.034901j (mag=0.340330, ang=-5.885975°)
# V3 = 0.272654-0.035408j (mag=0.274943, ang=-7.399239°)
# V4 = 0.313381-0.023240j (mag=0.314242, ang=-4.241258°)
#
# Iteração 28 - Correntes injetadas (modelo ZIP):
# I2 = -3.355531+4.126916j (mag=5.318931, ang=129.114025°)
# I3 = -1.079241+0.726979j (mag=1.301253, ang=146.035710°)
# I4 = -4.889396+2.915395j (mag=5.692603, ang=149.193691°)
#
# Iteração 28 - Novas tensões calculadas:
# V_novo2 = 0.319081-0.034093j (mag=0.320897, ang=-6.098788°)
# V_novo3 = 0.248736-0.033817j (mag=0.251024, ang=-7.742285°)
# V_novo4 = 0.292688-0.021677j (mag=0.293489, ang=-4.235663°)
#
# Iteração 29 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.319081-0.034093j (mag=0.320897, ang=-6.098788°)
# V3 = 0.248736-0.033817j (mag=0.251024, ang=-7.742285°)
# V4 = 0.292688-0.021677j (mag=0.293489, ang=-4.235663°)
#
# Iteração 29 - Correntes injetadas (modelo ZIP):
# I2 = -3.542454+4.390022j (mag=5.641035, ang=128.901212°)
# I3 = -1.177290+0.803314j (mag=1.425246, ang=145.692664°)
# I4 = -5.235430+3.121031j (mag=6.095126, ang=149.199286°)
#
# Iteração 29 - Novas tensões calculadas:
# V_novo2 = 0.291471-0.035915j (mag=0.293676, ang=-7.024627°)
# V_novo3 = 0.214418-0.035138j (mag=0.217278, ang=-9.306806°)
# V_novo4 = 0.263210-0.022623j (mag=0.264180, ang=-4.912425°)
#
# Iteração 30 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.291471-0.035915j (mag=0.293676, ang=-7.024627°)
# V3 = 0.214418-0.035138j (mag=0.217278, ang=-9.306806°)
# V4 = 0.263210-0.022623j (mag=0.264180, ang=-4.912425°)
#
# Iteração 30 - Correntes injetadas (modelo ZIP):
# I2 = -3.792802+4.858868j (mag=6.163923, ang=127.975373°)
# I3 = -1.334292+0.964868j (mag=1.646604, ang=144.128143°)
# I4 = -5.774904+3.535744j (mag=6.771336, ang=148.522524°)
#
# Iteração 30 - Novas tensões calculadas:
# V_novo2 = 0.244748-0.033280j (mag=0.247000, ang=-7.743453°)
# V_novo3 = 0.155776-0.029930j (mag=0.158625, ang=-10.875835°)
# V_novo4 = 0.213528-0.018141j (mag=0.214298, ang=-4.856069°)
#
# Iteração 31 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.244748-0.033280j (mag=0.247000, ang=-7.743453°)
# V3 = 0.155776-0.029930j (mag=0.158625, ang=-10.875835°)
# V4 = 0.213528-0.018141j (mag=0.214298, ang=-4.856069°)
#
# Iteração 31 - Correntes injetadas (modelo ZIP):
# I2 = -4.436688+5.833157j (mag=7.328705, ang=127.256547°)
# I3 = -1.790788+1.371187j (mag=2.255455, ang=142.559114°)
# I4 = -7.123435+4.351768j (mag=8.347527, ang=148.578880°)
#
# Iteração 31 - Novas tensões calculadas:
# V_novo2 = 0.135702-0.038432j (mag=0.141039, ang=-15.812759°)
# V_novo3 = 0.013976-0.030460j (mag=0.033514, ang=-65.352956°)
# V_novo4 = 0.097196-0.019803j (mag=0.099193, ang=-11.515758°)
#
# Iteração 32 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.135702-0.038432j (mag=0.141039, ang=-15.812759°)
# V3 = 0.013976-0.030460j (mag=0.033514, ang=-65.352956°)
# V4 = 0.097196-0.019803j (mag=0.099193, ang=-11.515758°)
#
# Iteração 32 - Correntes injetadas (modelo ZIP):
# I2 = -6.259027+11.205069j (mag=12.834680, ang=119.187241°)
# I3 = 0.357297+10.669394j (mag=10.675375, ang=88.081993°)
# I4 = -14.195369+11.122915j (mag=18.034071, ang=141.919191°)
#
# Iteração 32 - Novas tensões calculadas:
# V_novo2 = -0.523232+0.311074j (mag=0.608719, ang=149.267542°)
# V_novo3 = -0.827179+0.802222j (mag=1.152296, ang=135.877534°)
# V_novo4 = -0.601183+0.360719j (mag=0.701098, ang=149.035571°)
#
# Iteração 33 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = -0.523232+0.311074j (mag=0.608719, ang=149.267542°)
# V3 = -0.827179+0.802222j (mag=1.152296, ang=135.877534°)
# V4 = -0.601183+0.360719j (mag=0.701098, ang=149.035571°)
#
# Iteração 33 - Correntes injetadas (modelo ZIP):
# I2 = 0.732887-2.882050j (mag=2.973775, ang=-75.732458°)
# I3 = 0.102684-0.293014j (mag=0.310485, ang=-70.687518°)
# I4 = 1.369814-2.152621j (mag=2.551503, ang=-57.529480°)
#
# Iteração 33 - Novas tensões calculadas:
# V_novo2 = 0.896660-0.074926j (mag=0.899785, ang=-4.776576°)
# V_novo3 = 0.910189-0.085248j (mag=0.914172, ang=-5.350709°)
# V_novo4 = 0.904723-0.085242j (mag=0.908730, ang=-5.382474°)
#
# Iteração 34 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.896660-0.074926j (mag=0.899785, ang=-4.776576°)
# V3 = 0.910189-0.085248j (mag=0.914172, ang=-5.350709°)
# V4 = 0.904723-0.085242j (mag=0.908730, ang=-5.382474°)
#
# Iteração 34 - Correntes injetadas (modelo ZIP):
# I2 = -1.299164+1.536078j (mag=2.011806, ang=130.223424°)
# I3 = -0.332197+0.206901j (mag=0.391360, ang=148.084240°)
# I4 = -1.670356+1.041628j (mag=1.968522, ang=148.052475°)
#
# Iteração 34 - Novas tensões calculadas:
# V_novo2 = 0.577525-0.011557j (mag=0.577640, ang=-1.146383°)
# V_novo3 = 0.556449-0.012339j (mag=0.556586, ang=-1.270314°)
# V_novo4 = 0.568486-0.007094j (mag=0.568531, ang=-0.714956°)
#
# Iteração 35 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.577525-0.011557j (mag=0.577640, ang=-1.146383°)
# V3 = 0.556449-0.012339j (mag=0.556586, ang=-1.270314°)
# V4 = 0.568486-0.007094j (mag=0.568531, ang=-0.714956°)
#
# Iteração 35 - Correntes injetadas (modelo ZIP):
# I2 = -2.171135+2.259802j (mag=3.133773, ang=133.853617°)
# I3 = -0.568419+0.300142j (mag=0.642795, ang=152.164635°)
# I4 = -2.796496+1.442143j (mag=3.146453, ang=152.719993°)
#
# Iteração 35 - Novas tensões calculadas:
# V_novo2 = 0.496364-0.034848j (mag=0.497585, ang=-4.015923°)
# V_novo3 = 0.461841-0.038504j (mag=0.463443, ang=-4.765719°)
# V_novo4 = 0.481381-0.028903j (mag=0.482248, ang=-3.436068°)
#
# Iteração 36 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.496364-0.034848j (mag=0.497585, ang=-4.015923°)
# V3 = 0.461841-0.038504j (mag=0.463443, ang=-4.765719°)
# V4 = 0.481381-0.028903j (mag=0.482248, ang=-3.436068°)
#
# Iteração 36 - Correntes injetadas (modelo ZIP):
# I2 = -2.385950+2.746263j (mag=3.637955, ang=130.984077°)
# I3 = -0.659413+0.401415j (mag=0.771984, ang=148.669230°)
# I4 = -3.212406+1.854767j (mag=3.709409, ang=149.998881°)
#
# Iteração 36 - Novas tensões calculadas:
# V_novo2 = 0.456003-0.028026j (mag=0.456863, ang=-3.516989°)
# V_novo3 = 0.414342-0.029842j (mag=0.415415, ang=-4.119544°)
# V_novo4 = 0.438693-0.020184j (mag=0.439157, ang=-2.634311°)
#
# Iteração 37 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.456003-0.028026j (mag=0.456863, ang=-3.516989°)
# V3 = 0.414342-0.029842j (mag=0.415415, ang=-4.119544°)
# V4 = 0.438693-0.020184j (mag=0.439157, ang=-2.634311°)
#
# Iteração 37 - Correntes injetadas (modelo ZIP):
# I2 = -2.624568+2.968308j (mag=3.962223, ang=131.483011°)
# I3 = -0.740654+0.439499j (mag=0.861237, ang=149.315405°)
# I4 = -3.555770+1.987201j (mag=4.073386, ang=150.800638°)
#
# Iteração 37 - Novas tensões calculadas:
# V_novo2 = 0.431185-0.034203j (mag=0.432539, ang=-4.535374°)
# V_novo3 = 0.384720-0.036737j (mag=0.386470, ang=-5.454664°)
# V_novo4 = 0.412057-0.025857j (mag=0.412868, ang=-3.590602°)
#
# Iteração 38 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.431185-0.034203j (mag=0.432539, ang=-4.535374°)
# V3 = 0.384720-0.036737j (mag=0.386470, ang=-5.454664°)
# V4 = 0.412057-0.025857j (mag=0.412868, ang=-3.590602°)
#
# Iteração 38 - Correntes injetadas (modelo ZIP):
# I2 = -2.715999+3.184005j (mag=4.185038, ang=130.464626°)
# I3 = -0.784904+0.490838j (mag=0.925740, ang=147.980285°)
# I4 = -3.746376+2.176563j (mag=4.332755, ang=149.844347°)
#
# Iteração 38 - Novas tensões calculadas:
# V_novo2 = 0.412841-0.031021j (mag=0.414005, ang=-4.297130°)
# V_novo3 = 0.362843-0.032567j (mag=0.364301, ang=-5.128822°)
# V_novo4 = 0.392647-0.021804j (mag=0.393252, ang=-3.178370°)
#
# Iteração 39 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.412841-0.031021j (mag=0.414005, ang=-4.297130°)
# V3 = 0.362843-0.032567j (mag=0.364301, ang=-5.128822°)
# V4 = 0.392647-0.021804j (mag=0.393252, ang=-3.178370°)
#
# Iteração 39 - Correntes injetadas (modelo ZIP):
# I2 = -2.851397+3.314719j (mag=4.372393, ang=130.702870°)
# I3 = -0.835615+0.515963j (mag=0.982074, ang=148.306127°)
# I4 = -3.949589+2.256774j (mag=4.548877, ang=150.256579°)
#
# Iteração 39 - Novas tensões calculadas:
# V_novo2 = 0.398142-0.034514j (mag=0.399636, ang=-4.954474°)
# V_novo3 = 0.345104-0.036447j (mag=0.347024, ang=-6.028816°)
# V_novo4 = 0.376871-0.024989j (mag=0.377699, ang=-3.793542°)
#
# Iteração 40 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.398142-0.034514j (mag=0.399636, ang=-4.954474°)
# V3 = 0.345104-0.036447j (mag=0.347024, ang=-6.028816°)
# V4 = 0.376871-0.024989j (mag=0.377699, ang=-3.793542°)
#
# Iteração 40 - Correntes injetadas (modelo ZIP):
# I2 = -2.914334+3.467569j (mag=4.529611, ang=130.045526°)
# I3 = -0.868602+0.555363j (mag=1.030970, ang=147.406133°)
# I4 = -4.086761+2.393720j (mag=4.736192, ang=149.641406°)
#
# Iteração 40 - Novas tensões calculadas:
# V_novo2 = 0.384964-0.032167j (mag=0.386306, ang=-4.776387°)
# V_novo3 = 0.329258-0.033312j (mag=0.330939, ang=-5.777187°)
# V_novo4 = 0.362925-0.022011j (mag=0.363592, ang=-3.470720°)
#
# Iteração 41 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.384964-0.032167j (mag=0.386306, ang=-4.776387°)
# V3 = 0.329258-0.033312j (mag=0.330939, ang=-5.777187°)
# V4 = 0.362925-0.022011j (mag=0.363592, ang=-3.470720°)
#
# Iteração 41 - Correntes injetadas (modelo ZIP):
# I2 = -3.026029+3.577830j (mag=4.685906, ang=130.223613°)
# I3 = -0.913367+0.578350j (mag=1.081077, ang=147.657761°)
# I4 = -4.259261+2.462633j (mag=4.919946, ang=149.964229°)
#
# Iteração 41 - Novas tensões calculadas:
# V_novo2 = 0.372481-0.035054j (mag=0.374127, ang=-5.376285°)
# V_novo3 = 0.314068-0.036506j (mag=0.316183, ang=-6.630026°)
# V_novo4 = 0.349528-0.024633j (mag=0.350395, ang=-4.031336°)
#
# Iteração 42 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.372481-0.035054j (mag=0.374127, ang=-5.376285°)
# V3 = 0.314068-0.036506j (mag=0.316183, ang=-6.630026°)
# V4 = 0.349528-0.024633j (mag=0.350395, ang=-4.031336°)
#
# Iteração 42 - Correntes injetadas (modelo ZIP):
# I2 = -3.085684+3.726809j (mag=4.838445, ang=129.623715°)
# I3 = -0.946879+0.619504j (mag=1.131532, ang=146.804923°)
# I4 = -4.394469+2.598508j (mag=5.105252, ang=149.403613°)
#
# Iteração 42 - Novas tensões calculadas:
# V_novo2 = 0.359489-0.032672j (mag=0.360971, ang=-5.193027°)
# V_novo3 = 0.298332-0.033273j (mag=0.300181, ang=-6.363866°)
# V_novo4 = 0.335778-0.021625j (mag=0.336474, ang=-3.684981°)
#
# Iteração 43 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.359489-0.032672j (mag=0.360971, ang=-5.193027°)
# V3 = 0.298332-0.033273j (mag=0.300181, ang=-6.363866°)
# V4 = 0.335778-0.021625j (mag=0.336474, ang=-3.684981°)
#
# Iteração 43 - Correntes injetadas (modelo ZIP):
# I2 = -3.210486+3.852391j (mag=5.014791, ang=129.806973°)
# I3 = -1.000373+0.647887j (mag=1.191849, ang=147.071082°)
# I4 = -4.592554+2.678302j (mag=5.316470, ang=149.749968°)
#
# Iteração 43 - Novas tensões calculadas:
# V_novo2 = 0.345149-0.035918j (mag=0.347013, ang=-5.941084°)
# V_novo3 = 0.280730-0.036843j (mag=0.283137, ang=-7.476741°)
# V_novo4 = 0.320388-0.024563j (mag=0.321328, ang=-4.384087°)
#
# Iteração 44 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.345149-0.035918j (mag=0.347013, ang=-5.941084°)
# V3 = 0.280730-0.036843j (mag=0.283137, ang=-7.476741°)
# V4 = 0.320388-0.024563j (mag=0.321328, ang=-4.384087°)
#
# Iteração 44 - Correntes injetadas (modelo ZIP):
# I2 = -3.287016+4.050603j (mag=5.216498, ang=129.058916°)
# I3 = -1.047053+0.707358j (mag=1.263596, ang=145.958208°)
# I4 = -4.774444+2.863010j (mag=5.567059, ang=149.050862°)
#
# Iteração 44 - Novas tensões calculadas:
# V_novo2 = 0.327633-0.032573j (mag=0.329248, ang=-5.677674°)
# V_novo3 = 0.259326-0.032217j (mag=0.261320, ang=-7.081732°)
# V_novo4 = 0.301852-0.020367j (mag=0.302538, ang=-3.860054°)
#
# Iteração 45 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.327633-0.032573j (mag=0.329248, ang=-5.677674°)
# V3 = 0.259326-0.032217j (mag=0.261320, ang=-7.081732°)
# V4 = 0.301852-0.020367j (mag=0.302538, ang=-3.860054°)
#
# Iteração 45 - Correntes injetadas (modelo ZIP):
# I2 = -3.483964+4.253190j (mag=5.497966, ang=129.322326°)
# I3 = -1.139727+0.758575j (mag=1.369093, ang=146.353217°)
# I4 = -5.098581+2.994324j (mag=5.912825, ang=149.574895°)
#
# Iteração 45 - Novas tensões calculadas:
# V_novo2 = 0.304157-0.037773j (mag=0.306494, ang=-7.079317°)
# V_novo3 = 0.230138-0.037887j (mag=0.233236, ang=-9.348514°)
# V_novo4 = 0.276657-0.025059j (mag=0.277790, ang=-5.175526°)
#
# Iteração 46 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.304157-0.037773j (mag=0.306494, ang=-7.079317°)
# V3 = 0.230138-0.037887j (mag=0.233236, ang=-9.348514°)
# V4 = 0.276657-0.025059j (mag=0.277790, ang=-5.175526°)
#
# Iteração 46 - Correntes injetadas (modelo ZIP):
# I2 = -3.629735+4.659129j (mag=5.906137, ang=127.920683°)
# I3 = -1.242346+0.899757j (mag=1.533945, ang=144.086435°)
# I4 = -5.476484+3.387706j (mag=6.439599, ang=148.259423°)
#
# Iteração 46 - Novas tensões calculadas:
# V_novo2 = 0.267445-0.030142j (mag=0.269138, ang=-6.430302°)
# V_novo3 = 0.184569-0.026969j (mag=0.186528, ang=-8.313153°)
# V_novo4 = 0.237822-0.015609j (mag=0.238333, ang=-3.755138°)
#
# Iteração 47 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.267445-0.030142j (mag=0.269138, ang=-6.430302°)
# V3 = 0.184569-0.026969j (mag=0.186528, ang=-8.313153°)
# V4 = 0.237822-0.015609j (mag=0.238333, ang=-3.755138°)
#
# Iteração 47 - Correntes injetadas (modelo ZIP):
# I2 = -4.193360+5.258633j (mag=6.725882, ang=128.569698°)
# I3 = -1.573509+1.096806j (mag=1.918050, ang=145.121796°)
# I4 = -6.479042+3.789110j (mag=7.505687, ang=149.679810°)
#
# Iteração 47 - Novas tensões calculadas:
# V_novo2 = 0.194701-0.046042j (mag=0.200071, ang=-13.304542°)
# V_novo3 = 0.090992-0.043918j (mag=0.101037, ang=-25.764379°)
# V_novo4 = 0.159763-0.029961j (mag=0.162548, ang=-10.621493°)
#
# Iteração 48 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.194701-0.046042j (mag=0.200071, ang=-13.304542°)
# V3 = 0.090992-0.043918j (mag=0.101037, ang=-25.764379°)
# V4 = 0.159763-0.029961j (mag=0.162548, ang=-10.621493°)
#
# Iteração 48 - Correntes injetadas (modelo ZIP):
# I2 = -4.753740+7.698325j (mag=9.047776, ang=121.695458°)
# I3 = -2.163980+2.802838j (mag=3.541004, ang=127.670570°)
# I4 = -8.767453+6.651614j (mag=11.005099, ang=142.813456°)
#
# Iteração 48 - Novas tensões calculadas:
# V_novo2 = -0.049852+0.039431j (mag=0.063561, ang=141.657102°)
# V_novo3 = -0.231328+0.100706j (mag=0.252298, ang=156.474536°)
# V_novo4 = -0.097890+0.068973j (mag=0.119749, ang=144.831472°)
#
# Iteração 49 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = -0.049852+0.039431j (mag=0.063561, ang=141.657102°)
# V3 = -0.231328+0.100706j (mag=0.252298, ang=156.474536°)
# V4 = -0.097890+0.068973j (mag=0.119749, ang=144.831472°)
#
# Iteração 49 - Correntes injetadas (modelo ZIP):
# I2 = 3.301565-28.287644j (mag=28.479662, ang=-83.342898°)
# I3 = 0.909786-1.087726j (mag=1.418048, ang=-50.090515°)
# I4 = 7.074414-13.157080j (mag=14.938409, ang=-61.733580°)
#
# Iteração 49 - Novas tensões calculadas:
# V_novo2 = 1.978068-0.742431j (mag=2.112807, ang=-20.572685°)
# V_novo3 = 2.051776-0.764661j (mag=2.189632, ang=-20.439552°)
# V_novo4 = 2.020710-0.806048j (mag=2.175542, ang=-21.746735°)
#
# Iteração 50 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 1.978068-0.742431j (mag=2.112807, ang=-20.572685°)
# V3 = 2.051776-0.764661j (mag=2.189632, ang=-20.439552°)
# V4 = 2.020710-0.806048j (mag=2.175542, ang=-21.746735°)
#
# Iteração 50 - Correntes injetadas (modelo ZIP):
# I2 = -0.354308+0.780079j (mag=0.856772, ang=114.427315°)
# I3 = -0.111424+0.119507j (mag=0.163393, ang=132.995397°)
# I4 = -0.546864+0.614041j (mag=0.822257, ang=131.688214°)
#
# Iteração 50 - Novas tensões calculadas:
# V_novo2 = 0.661227+0.011747j (mag=0.661331, ang=1.017757°)
# V_novo3 = 0.652728+0.013637j (mag=0.652871, ang=1.196869°)
# V_novo4 = 0.658133+0.014588j (mag=0.658294, ang=1.269811°)
#
# Iteração 51 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.661227+0.011747j (mag=0.661331, ang=1.017757°)
# V3 = 0.652728+0.013637j (mag=0.652871, ang=1.196869°)
# V4 = 0.658133+0.014588j (mag=0.658294, ang=1.269811°)
#
# Iteração 51 - Correntes injetadas (modelo ZIP):
# I2 = -1.969565+1.900807j (mag=2.737198, ang=136.017757°)
# I3 = -0.495155+0.234780j (mag=0.547997, ang=154.631818°)
# I4 = -2.456858+1.161102j (mag=2.717409, ang=154.704760°)
#
# Iteração 51 - Novas tensões calculadas:
# V_novo2 = 0.527318-0.037199j (mag=0.528629, ang=-4.035137°)
# V_novo3 = 0.498058-0.041607j (mag=0.499793, ang=-4.775256°)
# V_novo4 = 0.514208-0.032519j (mag=0.515235, ang=-3.618582°)
#
# Iteração 52 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.527318-0.037199j (mag=0.528629, ang=-4.035137°)
# V3 = 0.498058-0.041607j (mag=0.499793, ang=-4.775256°)
# V4 = 0.514208-0.032519j (mag=0.515235, ang=-3.618582°)
#
# Iteração 52 - Correntes injetadas (modelo ZIP):
# I2 = -2.244970+2.585744j (mag=3.424319, ang=130.964863°)
# I3 = -0.611392+0.372322j (mag=0.715838, ang=148.659692°)
# I4 = -3.001189+1.745586j (mag=3.471917, ang=149.816367°)
#
# Iteração 52 - Novas tensões calculadas:
# V_novo2 = 0.472421-0.025761j (mag=0.473123, ang=-3.121279°)
# V_novo3 = 0.433798-0.027450j (mag=0.434665, ang=-3.620807°)
# V_novo4 = 0.456243-0.018371j (mag=0.456612, ang=-2.305837°)
#
# Iteração 53 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.472421-0.025761j (mag=0.473123, ang=-3.121279°)
# V3 = 0.433798-0.027450j (mag=0.434665, ang=-3.620807°)
# V4 = 0.456243-0.018371j (mag=0.456612, ang=-2.305837°)
#
# Iteração 53 - Correntes injetadas (modelo ZIP):
# I2 = -2.554105+2.848725j (mag=3.826054, ang=131.878721°)
# I3 = -0.711483+0.413858j (mag=0.823095, ang=149.814142°)
# I4 = -3.430738+1.891595j (mag=3.917664, ang=151.129111°)
#
# Iteração 53 - Novas tensões calculadas:
# V_novo2 = 0.442105-0.034659j (mag=0.443461, ang=-4.482537°)
# V_novo3 = 0.397724-0.037475j (mag=0.399485, ang=-5.382704°)
# V_novo4 = 0.423663-0.026738j (mag=0.424505, ang=-3.611225°)
#
# Iteração 54 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.442105-0.034659j (mag=0.443461, ang=-4.482537°)
# V3 = 0.397724-0.037475j (mag=0.399485, ang=-5.382704°)
# V4 = 0.423663-0.026738j (mag=0.424505, ang=-3.611225°)
#
# Iteração 54 - Correntes injetadas (modelo ZIP):
# I2 = -2.651971+3.103143j (mag=4.081966, ang=130.517463°)
# I3 = -0.759927+0.473892j (mag=0.895580, ang=148.052245°)
# I4 = -3.642908+2.118204j (mag=4.213973, ang=149.823724°)
#
# Iteração 54 - Novas tensões calculadas:
# V_novo2 = 0.421028-0.030226j (mag=0.422111, ang=-4.106336°)
# V_novo3 = 0.372663-0.031788j (mag=0.374016, ang=-4.875462°)
# V_novo4 = 0.401390-0.021255j (mag=0.401953, ang=-3.031227°)
#
# Iteração 55 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.421028-0.030226j (mag=0.422111, ang=-4.106336°)
# V3 = 0.372663-0.031788j (mag=0.374016, ang=-4.875462°)
# V4 = 0.401390-0.021255j (mag=0.401953, ang=-3.031227°)
#
# Iteração 55 - Correntes injetadas (modelo ZIP):
# I2 = -2.807448+3.241731j (mag=4.288425, ang=130.893664°)
# I3 = -0.816124+0.498957j (mag=0.956565, ang=148.559487°)
# I4 = -3.869751+2.197992j (mag=4.450409, ang=150.403722°)
#
# Iteração 55 - Novas tensões calculadas:
# V_novo2 = 0.404994-0.034691j (mag=0.406477, ang=-4.895942°)
# V_novo3 = 0.353345-0.036807j (mag=0.355256, ang=-5.946914°)
# V_novo4 = 0.384160-0.025426j (mag=0.385000, ang=-3.786705°)
#
# Iteração 56 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.404994-0.034691j (mag=0.406477, ang=-4.895942°)
# V3 = 0.353345-0.036807j (mag=0.355256, ang=-5.946914°)
# V4 = 0.384160-0.025426j (mag=0.385000, ang=-3.786705°)
#
# Iteração 56 - Correntes injetadas (modelo ZIP):
# I2 = -2.868762+3.406274j (mag=4.453369, ang=130.104058°)
# I3 = -0.849248+0.541280j (mag=1.007078, ang=147.488035°)
# I4 = -4.009537+2.347846j (mag=4.646372, ang=149.648244°)
#
# Iteração 56 - Novas tensões calculadas:
# V_novo2 = 0.391148-0.031720j (mag=0.392432, ang=-4.636181°)
# V_novo3 = 0.336737-0.032920j (mag=0.338342, ang=-5.583629°)
# V_novo4 = 0.369526-0.021760j (mag=0.370166, ang=-3.370024°)
#
# Iteração 57 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.391148-0.031720j (mag=0.392432, ang=-4.636181°)
# V3 = 0.336737-0.032920j (mag=0.338342, ang=-5.583629°)
# V4 = 0.369526-0.021760j (mag=0.370166, ang=-3.370024°)
#
# Iteração 57 - Correntes injetadas (modelo ZIP):
# I2 = -2.987397+3.514674j (mag=4.612752, ang=130.363819°)
# I3 = -0.895288+0.562674j (mag=1.057423, ang=147.851320°)
# I4 = -4.187863+2.411541j (mag=4.832569, ang=150.064925°)
#
# Iteração 57 - Novas tensões calculadas:
# V_novo2 = 0.378535-0.035139j (mag=0.380163, ang=-5.303563°)
# V_novo3 = 0.321407-0.036756j (mag=0.323502, ang=-6.523905°)
# V_novo4 = 0.355972-0.024944j (mag=0.356845, ang=-4.008273°)
#
# Iteração 58 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.378535-0.035139j (mag=0.380163, ang=-5.303563°)
# V3 = 0.321407-0.036756j (mag=0.323502, ang=-6.523905°)
# V4 = 0.355972-0.024944j (mag=0.356845, ang=-4.008273°)
#
# Iteração 58 - Correntes injetadas (modelo ZIP):
# I2 = -3.041345+3.663781j (mag=4.761625, ang=129.696437°)
# I3 = -0.926575+0.603772j (mag=1.105931, ang=146.911044°)
# I4 = -4.316068+2.549804j (mag=5.012978, ang=149.426676°)
#
# Iteração 58 - Novas tensões calculadas:
# V_novo2 = 0.365839-0.032351j (mag=0.367267, ang=-5.053499°)
# V_novo3 = 0.306068-0.033052j (mag=0.307848, ang=-6.163487°)
# V_novo4 = 0.342552-0.021514j (mag=0.343227, ang=-3.593711°)
#
# Iteração 59 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.365839-0.032351j (mag=0.367267, ang=-5.053499°)
# V3 = 0.306068-0.033052j (mag=0.307848, ang=-6.163487°)
# V4 = 0.342552-0.021514j (mag=0.343227, ang=-3.593711°)
#
# Iteração 59 - Correntes injetadas (modelo ZIP):
# I2 = -3.164662+3.778657j (mag=4.928827, ang=129.946501°)
# I3 = -0.977664+0.628337j (mag=1.162168, ang=147.271462°)
# I4 = -4.506369+2.618429j (mag=5.211865, ang=149.841238°)
#
# Iteração 59 - Novas tensões calculadas:
# V_novo2 = 0.352374-0.035932j (mag=0.354201, ang=-5.822402°)
# V_novo3 = 0.289564-0.037057j (mag=0.291925, ang=-7.292895°)
# V_novo4 = 0.328082-0.024840j (mag=0.329021, ang=-4.329696°)
#
# Iteração 60 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.352374-0.035932j (mag=0.354201, ang=-5.822402°)
# V3 = 0.289564-0.037057j (mag=0.291925, ang=-7.292895°)
# V4 = 0.328082-0.024840j (mag=0.329021, ang=-4.329696°)
#
# Iteração 60 - Correntes injetadas (modelo ZIP):
# I2 = -3.228527+3.961726j (mag=5.110642, ang=129.177598°)
# I3 = -1.017728+0.682801j (mag=1.225556, ang=146.142054°)
# I4 = -4.665469+2.791645j (mag=5.436900, ang=149.105253°)
#
# Iteração 60 - Novas tensões calculadas:
# V_novo2 = 0.336588-0.032355j (mag=0.338140, ang=-5.490722°)
# V_novo3 = 0.270340-0.032226j (mag=0.272254, ang=-6.797940°)
# V_novo4 = 0.311399-0.020458j (mag=0.312070, ang=-3.758782°)
#
# Iteração 61 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.336588-0.032355j (mag=0.338140, ang=-5.490722°)
# V3 = 0.270340-0.032226j (mag=0.272254, ang=-6.797940°)
# V4 = 0.311399-0.020458j (mag=0.312070, ang=-3.758782°)
#
# Iteração 61 - Correntes injetadas (modelo ZIP):
# I2 = -3.405843+4.130255j (mag=5.353389, ang=129.509278°)
# I3 = -1.097548+0.722683j (mag=1.314108, ang=146.637008°)
# I4 = -4.947970+2.894122j (mag=5.732220, ang=149.676167°)
#
# Iteração 61 - Novas tensões calculadas:
# V_novo2 = 0.316594-0.037582j (mag=0.318816, ang=-6.769729°)
# V_novo3 = 0.245552-0.038049j (mag=0.248482, ang=-8.808001°)
# V_novo4 = 0.289912-0.025303j (mag=0.291014, ang=-4.988090°)
#
# Iteração 62 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.316594-0.037582j (mag=0.318816, ang=-6.769729°)
# V3 = 0.245552-0.038049j (mag=0.248482, ang=-8.808001°)
# V4 = 0.289912-0.025303j (mag=0.291014, ang=-4.988090°)
#
# Iteração 62 - Correntes injetadas (modelo ZIP):
# I2 = -3.513590+4.460125j (mag=5.677854, ang=128.230271°)
# I3 = -1.174034+0.833512j (mag=1.439825, ang=144.626948°)
# I4 = -5.238170+3.216641j (mag=6.146967, ang=148.446859°)
#
# Iteração 62 - Novas tensões calculadas:
# V_novo2 = 0.287601-0.030602j (mag=0.289224, ang=-6.073582°)
# V_novo3 = 0.209789-0.028366j (mag=0.211698, ang=-7.700376°)
# V_novo4 = 0.259278-0.016822j (mag=0.259823, ang=-3.712247°)
#
# Iteração 63 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.287601-0.030602j (mag=0.289224, ang=-6.073582°)
# V3 = 0.209789-0.028366j (mag=0.211698, ang=-7.700376°)
# V4 = 0.259278-0.016822j (mag=0.259823, ang=-3.712247°)
#
# Iteração 63 - Correntes injetadas (modelo ZIP):
# I2 = -3.932533+4.869046j (mag=6.258788, ang=128.926418°)
# I3 = -1.396685+0.951519j (mag=1.690005, ang=145.734573°)
# I4 = -5.945760+3.471262j (mag=6.884891, ang=149.722702°)
#
# Iteração 63 - Novas tensões calculadas:
# V_novo2 = 0.237511-0.043569j (mag=0.241474, ang=-10.394760°)
# V_novo3 = 0.146127-0.042690j (mag=0.152235, ang=-16.285523°)
# V_novo4 = 0.205452-0.028844j (mag=0.207467, ang=-7.991622°)
#
# Iteração 64 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.237511-0.043569j (mag=0.241474, ang=-10.394760°)
# V3 = 0.146127-0.042690j (mag=0.152235, ang=-16.285523°)
# V4 = 0.205452-0.028844j (mag=0.207467, ang=-7.991622°)
#
# Iteração 64 - Correntes injetadas (modelo ZIP):
# I2 = -4.257364+6.170193j (mag=7.496428, ang=124.605240°)
# I3 = -1.722942+1.598289j (mag=2.350119, ang=137.149425°)
# I4 = -7.101087+4.890791j (mag=8.622371, ang=145.443327°)
#
# Iteração 64 - Novas tensões calculadas:
# V_novo2 = 0.116368-0.006086j (mag=0.116527, ang=-2.993626°)
# V_novo3 = -0.009111+0.014153j (mag=0.016832, ang=122.771529°)
# V_novo4 = 0.077708+0.015305j (mag=0.079201, ang=11.142095°)
#
# Iteração 65 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.116368-0.006086j (mag=0.116527, ang=-2.993626°)
# V3 = -0.009111+0.014153j (mag=0.016832, ang=122.771529°)
# V4 = 0.077708+0.015305j (mag=0.079201, ang=11.142095°)
#
# Iteração 65 - Correntes injetadas (modelo ZIP):
# I2 = -10.395916+11.543251j (mag=15.534533, ang=132.006374°)
# I3 = 2.297899-21.130264j (mag=21.254844, ang=-83.793522°)
# I4 = -21.773033+6.006679j (mag=22.586393, ang=164.577044°)
#
# Iteração 65 - Novas tensões calculadas:
# V_novo2 = 0.098032-0.781178j (mag=0.787305, ang=-82.847204°)
# V_novo3 = 0.835096-1.663541j (mag=1.861385, ang=-63.343379°)
# V_novo4 = -0.016033-0.761432j (mag=0.761601, ang=-91.206285°)
#
# Iteração 66 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.098032-0.781178j (mag=0.787305, ang=-82.847204°)
# V3 = 0.835096-1.663541j (mag=1.861385, ang=-63.343379°)
# V4 = -0.016033-0.761432j (mag=0.761601, ang=-91.206285°)
#
# Iteração 66 - Correntes injetadas (modelo ZIP):
# I2 = 1.410708+1.815584j (mag=2.299227, ang=52.152796°)
# I3 = -0.000307+0.192207j (mag=0.192207, ang=90.091570°)
# I4 = 1.094413+2.078259j (mag=2.348808, ang=62.228664°)
#
# Iteração 66 - Novas tensões calculadas:
# V_novo2 = 0.684401+0.154482j (mag=0.701619, ang=12.719532°)
# V_novo3 = 0.678759+0.162993j (mag=0.698055, ang=13.503008°)
# V_novo4 = 0.688949+0.165611j (mag=0.708574, ang=13.516408°)
#
# Iteração 67 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.684401+0.154482j (mag=0.701619, ang=12.719532°)
# V3 = 0.678759+0.162993j (mag=0.698055, ang=13.503008°)
# V4 = 0.688949+0.165611j (mag=0.708574, ang=13.516408°)
#
# Iteração 67 - Correntes injetadas (modelo ZIP):
# I2 = -2.181266+1.377899j (mag=2.580024, ang=147.719532°)
# I3 = -0.499264+0.115834j (mag=0.512525, ang=166.937957°)
# I4 = -2.459395+0.569996j (mag=2.524582, ang=166.951357°)
#
# Iteração 67 - Novas tensões calculadas:
# V_novo2 = 0.550886-0.071419j (mag=0.555496, ang=-7.386872°)
# V_novo3 = 0.525005-0.081315j (mag=0.531265, ang=-8.804261°)
# V_novo4 = 0.538058-0.069756j (mag=0.542561, ang=-7.386845°)
#
# Iteração 68 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.550886-0.071419j (mag=0.555496, ang=-7.386872°)
# V3 = 0.525005-0.081315j (mag=0.531265, ang=-8.804261°)
# V4 = 0.538058-0.069756j (mag=0.542561, ang=-7.386845°)
#
# Iteração 68 - Correntes injetadas (modelo ZIP):
# I2 = -1.988868+2.581374j (mag=3.258695, ang=127.613128°)
# I3 = -0.549142+0.389813j (mag=0.673433, ang=144.630688°)
# ...
# V_novo2 = 0.333364-0.043457j (mag=0.336184, ang=-7.427150°)
# V_novo3 = 0.266063-0.045775j (mag=0.269972, ang=-9.762017°)
# V_novo4 = 0.307563-0.032167j (mag=0.309240, ang=-5.970652°)
#
# Iteração 94 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.333364-0.043457j (mag=0.336184, ang=-7.427150°)
# V3 = 0.266063-0.045775j (mag=0.269972, ang=-9.762017°)
# V4 = 0.307563-0.032167j (mag=0.309240, ang=-5.970652°)
#
# Iteração 94 - Correntes injetadas (modelo ZIP):
# I2 = -3.283321+4.267661j (mag=5.384527, ang=127.572850°)
# I3 = -1.067658+0.785050j (mag=1.325216, ang=143.672932°)
# I4 = -4.876806+3.111142j (mag=5.784673, ang=147.464297°)
#
# Iteração 94 - Novas tensões calculadas:
# V_novo2 = 0.312166-0.022524j (mag=0.312977, ang=-4.127017°)
# V_novo3 = 0.240601-0.019284j (mag=0.241373, ang=-4.582370°)
# V_novo4 = 0.285739-0.009103j (mag=0.285884, ang=-1.824729°)
#
# Iteração 95 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.312166-0.022524j (mag=0.312977, ang=-4.127017°)
# V3 = 0.240601-0.019284j (mag=0.241373, ang=-4.582370°)
# V4 = 0.285739-0.009103j (mag=0.285884, ang=-1.824729°)
#
# Iteração 95 - Correntes injetadas (modelo ZIP):
# I2 = -3.784820+4.373482j (mag=5.783788, ang=130.872983°)
# I3 = -1.268554+0.766674j (mag=1.482234, ang=148.852579°)
# I4 = -5.504738+2.975132j (mag=6.257280, ang=151.610220°)
#
# Iteração 95 - Novas tensões calculadas:
# V_novo2 = 0.281863-0.054667j (mag=0.287115, ang=-10.976277°)
# V_novo3 = 0.201795-0.058278j (mag=0.210041, ang=-16.108618°)
# V_novo4 = 0.252300-0.042253j (mag=0.255814, ang=-9.507193°)
#
# Iteração 96 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.281863-0.054667j (mag=0.287115, ang=-10.976277°)
# V3 = 0.201795-0.058278j (mag=0.210041, ang=-16.108618°)
# V4 = 0.252300-0.042253j (mag=0.255814, ang=-9.507193°)
#
# Iteração 96 - Correntes injetadas (modelo ZIP):
# I2 = -3.527745+5.225429j (mag=6.304767, ang=124.023723°)
# I3 = -1.252337+1.154558j (mag=1.703336, ang=137.326331°)
# I4 = -5.652101+4.117390j (mag=6.992793, ang=143.927756°)
#
# Iteração 96 - Novas tensões calculadas:
# V_novo2 = 0.229338+0.004554j (mag=0.229383, ang=1.137522°)
# V_novo3 = 0.138371+0.018910j (mag=0.139657, ang=7.782134°)
# V_novo4 = 0.198454+0.022721j (mag=0.199751, ang=6.531461°)
#
# Iteração 97 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.229338+0.004554j (mag=0.229383, ang=1.137522°)
# V3 = 0.138371+0.018910j (mag=0.139657, ang=7.782134°)
# V4 = 0.198454+0.022721j (mag=0.199751, ang=6.531461°)
#
# Iteração 97 - Correntes injetadas (modelo ZIP):
# I2 = -5.689873+5.468315j (mag=7.891586, ang=136.137522°)
# I3 = -2.425358+0.824853j (mag=2.561785, ang=161.217083°)
# I4 = -8.413561+3.067873j (mag=8.955437, ang=159.966409°)
#
# Iteração 97 - Novas tensões calculadas:
# V_novo2 = 0.111753-0.164344j (mag=0.198740, ang=-55.784537°)
# V_novo3 = -0.022182-0.200011j (mag=0.201237, ang=-96.328539°)
# V_novo4 = 0.067306-0.152906j (mag=0.167064, ang=-66.242008°)
#
# Iteração 98 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.111753-0.164344j (mag=0.198740, ang=-55.784537°)
# V3 = -0.022182-0.200011j (mag=0.201237, ang=-96.328539°)
# V4 = 0.067306-0.152906j (mag=0.167064, ang=-66.242008°)
#
# Iteração 98 - Correntes injetadas (modelo ZIP):
# I2 = 1.704321+8.947481j (mag=9.108354, ang=79.215463°)
# I3 = 0.965518+1.492830j (mag=1.777854, ang=57.106410°)
# I4 = 0.524380+10.694733j (mag=10.707581, ang=87.192941°)
#
# Iteração 98 - Novas tensões calculadas:
# V_novo2 = 0.303470+0.573385j (mag=0.648741, ang=62.109552°)
# V_novo3 = 0.302329+0.669561j (mag=0.734652, ang=65.699237°)
# V_novo4 = 0.300813+0.628185j (mag=0.696494, ang=64.412044°)
#
# Iteração 99 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.303470+0.573385j (mag=0.648741, ang=62.109552°)
# V3 = 0.302329+0.669561j (mag=0.734652, ang=65.699237°)
# V4 = 0.300813+0.628185j (mag=0.696494, ang=64.412044°)
#
# Iteração 99 - Correntes injetadas (modelo ZIP):
# I2 = -2.666831-0.820911j (mag=2.790319, ang=-162.890448°)
# I3 = -0.377746-0.307360j (mag=0.486993, ang=-140.865814°)
# I4 = -2.028118-1.575835j (mag=2.568369, ang=-142.153007°)
#
# Iteração 99 - Novas tensões calculadas:
# V_novo2 = 0.663563-0.182510j (mag=0.688205, ang=-15.378715°)
# V_novo3 = 0.655837-0.207853j (mag=0.687986, ang=-17.584851°)
# V_novo4 = 0.654004-0.191578j (mag=0.681486, ang=-16.326973°)
#
# Iteração 100 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.663563-0.182510j (mag=0.688205, ang=-15.378715°)
# V3 = 0.655837-0.207853j (mag=0.687986, ang=-17.584851°)
# V4 = 0.654004-0.191578j (mag=0.681486, ang=-16.326973°)
#
# Iteração 100 - Correntes injetadas (modelo ZIP):
# I2 = -1.300071+2.286560j (mag=2.630312, ang=119.621285°)
# I3 = -0.373129+0.362218j (mag=0.520026, ang=135.850098°)
# I4 = -1.923123+1.786577j (mag=2.624930, ang=137.107976°)
#
# Iteração 100 - Novas tensões calculadas:
# V_novo2 = 0.532102+0.020584j (mag=0.532500, ang=2.215360°)
# V_novo3 = 0.504526+0.025580j (mag=0.505174, ang=2.902517°)
# V_novo4 = 0.521403+0.028721j (mag=0.522193, ang=3.152890°)
# Atenção: Atingido número máximo de iterações (100)
#
# Executando cenário: 100% Corrente Constante
#
# Constantes C:
# C2 = -0.720419+0.000425j
# C3 = -0.720527+0.000588j
# C4 = -0.720421+0.000444j
#
# Modelos de Carga Configurados:
# Barra 2: 0.0% Potência Constante, 100.0% Corrente Constante, 0.0% Impedância Constante
# Barra 3: 0.0% Potência Constante, 100.0% Corrente Constante, 0.0% Impedância Constante
# Barra 4: 0.0% Potência Constante, 100.0% Corrente Constante, 0.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V_novo3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V_novo4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -1.231510+1.326719j (mag=1.810193, ang=132.868635°)
# I3 = -0.312853+0.173560j (mag=0.357771, ang=150.979980°)
# I4 = -1.573449+0.851034j (mag=1.788854, ang=151.592288°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.591966-0.017510j (mag=0.592224, ang=-1.694283°)
# V_novo3 = 0.572762-0.019217j (mag=0.573084, ang=-1.921651°)
# V_novo4 = 0.583517-0.013971j (mag=0.583684, ang=-1.371594°)
#
# Iteração 3 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.591966-0.017510j (mag=0.592224, ang=-1.694283°)
# V3 = 0.572762-0.019217j (mag=0.573084, ang=-1.921651°)
# V4 = 0.583517-0.013971j (mag=0.583684, ang=-1.371594°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -1.241595+1.317286j (mag=1.810193, ang=133.305717°)
# I3 = -0.314455+0.170641j (mag=0.357771, ang=151.513298°)
# I4 = -1.580392+0.838069j (mag=1.788854, ang=152.063355°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.592115-0.018542j (mag=0.592405, ang=-1.793653°)
# V_novo3 = 0.572927-0.020429j (mag=0.573291, ang=-2.042156°)
# V_novo4 = 0.583637-0.015073j (mag=0.583832, ang=-1.479418°)
#
# Iteração 4 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.592115-0.018542j (mag=0.592405, ang=-1.793653°)
# V3 = 0.572927-0.020429j (mag=0.573291, ang=-2.042156°)
# V4 = 0.583637-0.015073j (mag=0.583832, ang=-1.479418°)
#
# Iteração 4 - Correntes injetadas (modelo ZIP):
# I2 = -1.239309+1.319437j (mag=1.810193, ang=133.206347°)
# I3 = -0.314095+0.171302j (mag=0.357771, ang=151.392793°)
# I4 = -1.578812+0.841042j (mag=1.788854, ang=151.955531°)
#
# Iteração 4 - Novas tensões calculadas:
# V_novo2 = 0.592080-0.018307j (mag=0.592363, ang=-1.771025°)
# V_novo3 = 0.572888-0.020153j (mag=0.573243, ang=-2.014751°)
# V_novo4 = 0.583609-0.014822j (mag=0.583797, ang=-1.454854°)
#
# Executando cenário: 100% Impedância Constante
#
# Constantes C:
# C2 = -0.720419+0.000425j
# C3 = -0.720527+0.000588j
# C4 = -0.720421+0.000444j
#
# Modelos de Carga Configurados:
# Barra 2: 0.0% Potência Constante, 0.0% Corrente Constante, 100.0% Impedância Constante
# Barra 3: 0.0% Potência Constante, 0.0% Corrente Constante, 100.0% Impedância Constante
# Barra 4: 0.0% Potência Constante, 0.0% Corrente Constante, 100.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V_novo3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V_novo4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -0.730319+0.786780j (mag=1.073494, ang=132.868635°)
# I3 = -0.179585+0.099628j (mag=0.205369, ang=150.979980°)
# I4 = -0.919461+0.497311j (mag=1.045335, ang=151.592288°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.644954-0.010353j (mag=0.645037, ang=-0.919651°)
# V_novo3 = 0.633977-0.011402j (mag=0.634079, ang=-1.030317°)
# V_novo4 = 0.640018-0.008293j (mag=0.640071, ang=-0.742347°)
#
# Iteração 3 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.644954-0.010353j (mag=0.645037, ang=-0.919651°)
# V3 = 0.633977-0.011402j (mag=0.634079, ang=-1.030317°)
# V4 = 0.640018-0.008293j (mag=0.640071, ang=-0.742347°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -0.812290+0.838793j (mag=1.167642, ang=134.080349°)
# I3 = -0.201048+0.105085j (mag=0.226855, ang=152.404631°)
# I4 = -1.017394+0.525283j (mag=1.144995, ang=152.692601°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.638205-0.013026j (mag=0.638338, ang=-1.169250°)
# V_novo3 = 0.626096-0.014472j (mag=0.626264, ang=-1.324091°)
# V_novo4 = 0.632755-0.010872j (mag=0.632849, ang=-0.984337°)
#
# Iteração 4 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.638205-0.013026j (mag=0.638338, ang=-1.169250°)
# V3 = 0.626096-0.014472j (mag=0.626264, ang=-1.324091°)
# V4 = 0.632755-0.010872j (mag=0.632849, ang=-0.984337°)
#
# Iteração 4 - Correntes injetadas (modelo ZIP):
# I2 = -0.800230+0.833576j (mag=1.155516, ang=133.830750°)
# I3 = -0.198035+0.104806j (mag=0.224059, ang=152.110857°)
# I4 = -1.003711+0.523599j (mag=1.132074, ang=152.450612°)
#
# Iteração 4 - Novas tensões calculadas:
# V_novo2 = 0.639052-0.012525j (mag=0.639175, ang=-1.122860°)
# V_novo3 = 0.627087-0.013893j (mag=0.627241, ang=-1.269210°)
# V_novo4 = 0.633673-0.010373j (mag=0.633758, ang=-0.937844°)
#
# Iteração 5 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.639052-0.012525j (mag=0.639175, ang=-1.122860°)
# V3 = 0.627087-0.013893j (mag=0.627241, ang=-1.269210°)
# V4 = 0.633673-0.010373j (mag=0.633758, ang=-0.937844°)
#
# Iteração 5 - Correntes injetadas (modelo ZIP):
# I2 = -0.801954+0.834019j (mag=1.157030, ang=133.877140°)
# I3 = -0.198445+0.104780j (mag=0.224409, ang=152.165739°)
# I4 = -1.005578+0.523535j (mag=1.133700, ang=152.497105°)
#
# Iteração 5 - Novas tensões calculadas:
# V_novo2 = 0.638949-0.012610j (mag=0.639074, ang=-1.130647°)
# V_novo3 = 0.626967-0.013992j (mag=0.627123, ang=-1.278435°)
# V_novo4 = 0.633560-0.010459j (mag=0.633647, ang=-0.945796°)
#
# Executando cenário: Modelo Misto (ZIP)
#
# Constantes C:
# C2 = -0.720419+0.000425j
# C3 = -0.720527+0.000588j
# C4 = -0.720421+0.000444j
#
# Modelos de Carga Configurados:
# Barra 2: 40.0% Potência Constante, 30.0% Corrente Constante, 30.0% Impedância Constante
# Barra 3: 40.0% Potência Constante, 30.0% Corrente Constante, 30.0% Impedância Constante
# Barra 4: 40.0% Potência Constante, 30.0% Corrente Constante, 30.0% Impedância Constante
#
# Iteração 1 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V3 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
# V4 = 1.000000+0.000000j (mag=1.000000, ang=0.000000°)
#
# Iteração 1 - Correntes injetadas (modelo ZIP):
# I2 = -1.280000+1.280000j (mag=1.810193, ang=135.000000°)
# I3 = -0.320000+0.160000j (mag=0.357771, ang=153.434949°)
# I4 = -1.600000+0.800000j (mag=1.788854, ang=153.434949°)
#
# Iteração 1 - Novas tensões calculadas:
# V_novo2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V_novo3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V_novo4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.592617-0.022055j (mag=0.593027, ang=-2.131365°)
# V3 = 0.573498-0.024588j (mag=0.574024, ang=-2.454969°)
# V4 = 0.584058-0.018790j (mag=0.584360, ang=-1.842661°)
#
# Iteração 2 - Correntes injetadas (modelo ZIP):
# I2 = -1.419209+1.528928j (mag=2.086091, ang=132.868635°)
# I3 = -0.365738+0.202899j (mag=0.418249, ang=150.979980°)
# I4 = -1.824913+0.987044j (mag=2.074744, ang=151.592288°)
#
# Iteração 2 - Novas tensões calculadas:
# V_novo2 = 0.571775-0.020289j (mag=0.572135, ang=-2.032292°)
# V_novo3 = 0.549307-0.022258j (mag=0.549758, ang=-2.320373°)
# V_novo4 = 0.561976-0.016182j (mag=0.562209, ang=-1.649406°)
#
# Iteração 3 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.571775-0.020289j (mag=0.572135, ang=-2.032292°)
# V3 = 0.549307-0.022258j (mag=0.549758, ang=-2.320373°)
# V4 = 0.561976-0.016182j (mag=0.562209, ang=-1.649406°)
#
# Iteração 3 - Correntes injetadas (modelo ZIP):
# I2 = -1.444507+1.550795j (mag=2.119331, ang=132.967708°)
# I3 = -0.373568+0.206097j (mag=0.426649, ang=151.114576°)
# I4 = -1.860270+0.998073j (mag=2.111103, ang=151.785543°)
#
# Iteração 3 - Novas tensões calculadas:
# V_novo2 = 0.569316-0.021032j (mag=0.569704, ang=-2.115722°)
# V_novo3 = 0.546399-0.023091j (mag=0.546887, ang=-2.419939°)
# V_novo4 = 0.559331-0.016887j (mag=0.559585, ang=-1.729274°)
#
# Iteração 4 - Tensões atuais:
# V1 = 0.720000+0.000000j (mag=0.720000, ang=0.000000°)
# V2 = 0.569316-0.021032j (mag=0.569704, ang=-2.115722°)
# V3 = 0.546399-0.023091j (mag=0.546887, ang=-2.419939°)
# V4 = 0.559331-0.016887j (mag=0.559585, ang=-1.729274°)
#
# Iteração 4 - Correntes injetadas (modelo ZIP):
# I2 = -1.445023+1.555886j (mag=2.123411, ang=132.884278°)
# I3 = -0.374136+0.207259j (mag=0.427707, ang=151.015009°)
# I4 = -1.862891+1.002826j (mag=2.115661, ang=151.705675°)
#
# Iteração 4 - Novas tensões calculadas:
# V_novo2 = 0.568972-0.020859j (mag=0.569354, ang=-2.099528°)
# V_novo3 = 0.545995-0.022882j (mag=0.546474, ang=-2.399823°)
# V_novo4 = 0.558971-0.016690j (mag=0.559220, ang=-1.710244°)
#
# --- Comparação de Resultados entre Cenários de Carga ---
# Cenário                        Iterações  Magnitudes de Tensão (pu)                Ângulos de Fase (°)
# 100% Potência Constante        100        0.7200, 0.5325, 0.5052, 0.5222           0.00, 2.22, 2.90, 3.15
# 100% Corrente Constante        4          0.7200, 0.5924, 0.5732, 0.5838           0.00, -1.77, -2.01, -1.45
# 100% Impedância Constante      5          0.7200, 0.6391, 0.6271, 0.6336           0.00, -1.13, -1.28, -0.95
# Modelo Misto (ZIP)             4          0.7200, 0.5694, 0.5465, 0.5592           0.00, -2.10, -2.40, -1.71
